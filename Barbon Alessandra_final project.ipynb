# %%
# The following preliminary analyses come from a Visual Search Task performed by two different samples: older vs younger adults.

# In this particular task: 
# the set size of the stimuli presented varied according to 3 levels (5, 7 or 10 stimuli in total displayed);
# the difficulty of the visual search also varied according to 3 levels 
### (Baseline, where stimuli could come from any conceptual category -such as kitchen materials, tools, clothing, ...- and any color category -such as blue, brown, black,...-;
### High Concept, where stimuli could come only from one conceptual category but could be in different colors;
### High Color, where stimuli could only be in one color but could come from different conceptual categories);
# the Target that had to be searched for could be present or not.

# Both Reaction Time (RT) and accuracy were measured.

import numpy as np
import pandas as pd
import random
import itertools
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import seaborn as sns

# %%
# STEP 1. generation of some data

# ensure reproducibility by putting a seed
np.random.seed(42)
random.seed(42)

# define variables levels
Nfig_levels = [5, 7, 10]  
Tipo_levels = ['Baseline', 'Hconc', 'Hcol'] 
TargetPresence_levels = ['T', 'NoT']
Group_levels = ['OLD', 'YOUNG']

# define the sample size
n_samples = 30

# define the number of participants per group
n_participants_per_group = 30

# define the total number of participants
n_participants_tot = n_participants_per_group * len(Group_levels)

# define the total number of trials for each combination of conditions
total_trials_per_condition = 40

# create a function for the data generation according to some boundaries
def generate_ideal_data():
    data = []
    # initialize participant ID
    participant_id = 1 
    
    # loop through each group level (YOUNG and OLD)
    for group in Group_levels:
        # loop through each participant within the group
        for _ in range(n_participants_per_group):
            # loop through each combination of Nfig, Tipo, and TargetPresence levels (so that it will generate RT and accuracy based on these combinations)
            for Nfig, Tipo, TargetPresence in itertools.product(Nfig_levels, Tipo_levels, TargetPresence_levels): # itertools.product to generate all possible combinations of the levels of the independent variables
                # define the baseline of RT according to the group
                if group == 'YOUNG':
                    base_rt = 0.71
                else:  # Group == 'OLD'
                    base_rt = 0.89
                # YOUNG are faster than OLD
                    
                # generate RT as a function of the predictors
                rt_nfig = (Nfig - 5) * 1.13  # increase by 1.45 for each additional level of difficulty compared to the easier level
                rt_tipo = 0.91 if Tipo == 'Baseline' else (1.09 if Tipo == 'Hconc' else 1.2) # adjusting RT based on Tipo
                rt_target = 0.8 if TargetPresence == 'T' else 1.56 # adjusting RT based on TargetPresence
                rt_group = 0.97 if group == 'YOUNG' else 1.1 # adjusting RT based on Group
                
                # apply the baseline value
                rt = base_rt * (1 + (rt_nfig + rt_tipo + rt_target + rt_group) / 100)
                
                # Add interaction effects (e.g., Tipo might interact with TargetPresence)
                if Tipo != 'Baseline' and TargetPresence == 'NoT':
                    rt += 0.15  # Increase RT for non-baseline tasks when target is not present

                # Add some random noise for RT, with higher noise for more difficult tasks
                difficulty = rt_nfig + rt_tipo + rt_target + rt_group
                noise_level = 0.3 + 0.1 * (difficulty / 50)  # Increase noise with difficulty
                rt += np.random.normal(0, noise_level)
                
                # add some random noise for RT
                #rt += random.normalvariate(0, 0.3)
                
                # boundaries for RT (ex. no negative values but also not too close to 0)
                rt = max(0.15, min(rt, 4))
                
                # Add small random buffer to avoid hitting the exact boundaries
                if rt == 0.15:
                    rt += np.random.uniform(0.01, 0.02)  # Slightly increase to avoid the lower boundary
                if rt == 4:
                    rt -= np.random.uniform(0.01, 0.02)  # Slightly decrease to avoid the upper boundary

                # the resulting RT will be the mean RT for each participant for each condition combination
                    
                # define the baseline of Accuracy according to the group
                if group == 'YOUNG':
                    base_accuracy = 0.87
                else:  # Group == 'OLD'
                    base_accuracy = 0.96
                # OLD are more accurate than YOUNG
                
                # generate accuracy as a function of the predictors
                acc_nfig = -0.01 if Nfig == 5 else (-0.09 if Nfig == 7 else -0.13)  # adjust accuracy based on Nfig (decreasing with higher Nfig)
                acc_tipo = 0.02 if Tipo == 'Baseline' else (-0.03 if Tipo == 'Hconc' else -0.06) # adjust accuracy based on Tipo
                acc_target = 0 if TargetPresence == 'NoT' else -0.05 # adjust accuracy based on TargetPresence
                acc_group = 0.03 if group == 'OLD' else -0.03 # adjust accuracy based on Group
                
                # apply the baseline value
                accuracy = base_accuracy + acc_nfig + acc_tipo + acc_target + acc_group
                
                # Add interaction effects (e.g., Tipo might interact with TargetPresence)
                if Tipo != 'Baseline' and TargetPresence == 'T':
                    accuracy -= 0.02  # Decrease accuracy for non-baseline tasks when target is present

                # Add some random noise for Accuracy, with higher noise for more difficult tasks
                difficulty = abs(acc_nfig) + abs(acc_tipo) + abs(acc_target) + abs(acc_group)
                noise_level = 0.05 + 0.02 * (difficulty / 0.5)  # Increase noise with difficulty
                accuracy += np.random.normal(0, noise_level)
                
                # add some random noise for Accuracy
                #accuracy += random.normalvariate(0, 0.3)
                
                # boundaries for Accuracy 0.65 e 1
                accuracy = max(0.65, min(1, accuracy))
                
                # Add small random buffer to avoid hitting the exact boundaries
                if accuracy == 0.65:
                    accuracy += np.random.uniform(0.01, 0.02)  # Slightly increase to avoid the lower boundary
                
                # the resulting Accuracy will be the mean accuracy for each participant for each condition combination
                
                # calculate the number of correct trials based on accuracy
                correct_trials = round(accuracy * total_trials_per_condition)
                
                data.append([participant_id, Nfig, Tipo, TargetPresence, group, rt, accuracy, correct_trials])
            
            participant_id += 1
    
    return pd.DataFrame(data, columns=['ID', 'Nfig', 'Tipo', 'TargetPresence', 'Group', 'RT', 'Accuracy', 'correct_trials'])

# generate data
df_ideal = generate_ideal_data()

print(df_ideal.head(50))
print(df_ideal.tail(50))

# Save to an Excel file
df_ideal.to_excel('ideal_data.xlsx', index=False)
# Out:
#     ID  Nfig      Tipo TargetPresence Group        RT  Accuracy  \
# 0    1     5  Baseline              T   OLD  1.066815  0.942478
# 1    1     5  Baseline            NoT   OLD  1.120704  1.000000
# 2    1     5     Hconc              T   OLD  0.844965  0.867169
# 3    1     5     Hconc            NoT   OLD  1.558983  0.990521
# 4    1     5      Hcol              T   OLD  0.773837  0.880383
# 5    1     5      Hcol            NoT   OLD  0.931751  0.894851
# 6    1     7  Baseline              T   OLD  1.010165  0.759795
# 7    1     7  Baseline            NoT   OLD  0.404299  0.888737
# 8    1     7     Hconc              T   OLD  0.622241  0.818226
# 9    1     7     Hconc            NoT   OLD  0.810167  0.790911
# 10   1     7      Hcol              T   OLD  1.393110  0.756634
# 11   1     7      Hcol            NoT   OLD  1.115553  0.758504
# 12   1    10  Baseline              T   OLD  0.792768  0.836567
# 13   1    10  Baseline            NoT   OLD  0.605536  0.901490
# 14   1    10     Hconc              T   OLD  0.776325  0.742615
# 15   1    10     Hconc            NoT   OLD  0.931836  0.936691
# 16   1    10      Hcol              T   OLD  0.963590  0.665691
# 17   1    10      Hcol            NoT   OLD  1.387047  0.728214
# 18   2     5  Baseline              T   OLD  0.978842  0.843394
# 19   2     5  Baseline            NoT   OLD  0.513834  1.000000
# 20   2     5     Hconc              T   OLD  1.142567  0.889391
# 21   2     5     Hconc            NoT   OLD  1.037813  0.934102
# 22   2     5      Hcol              T   OLD  0.464867  0.809689
# 23   2     5      Hcol            NoT   OLD  0.932606  0.977085
# 24   2     7  Baseline              T   OLD  1.041693  0.768449
# 25   2     7  Baseline            NoT   OLD  1.042891  0.898589
# 26   2     7     Hconc              T   OLD  0.726541  0.835477
# 27   2     7     Hconc            NoT   OLD  1.415181  0.922152
# 28   2     7      Hcol              T   OLD  0.676942  0.751695
# 29   2     7      Hcol            NoT   OLD  1.197902  0.895801
# 30   2    10  Baseline              T   OLD  0.813434  0.819009
# 31   2    10  Baseline            NoT   OLD  0.619757  0.811577
# 32   2    10     Hconc              T   OLD  1.224694  0.840832
# 33   2    10     Hconc            NoT   OLD  1.100703  0.887803
# 34   2    10      Hcol              T   OLD  1.082694  0.690777
# 35   2    10      Hcol            NoT   OLD  1.239931  0.890437
# 36   3     5  Baseline              T   OLD  0.904060  1.000000
# 37   3     5  Baseline            NoT   OLD  0.160254  1.000000
# 38   3     5     Hconc              T   OLD  0.482502  0.937129
# 39   3     5     Hconc            NoT   OLD  1.351211  0.951003
# 40   3     5      Hcol              T   OLD  0.753952  0.766277
# 41   3     5      Hcol            NoT   OLD  0.831483  0.960160
# 42   3     7  Baseline              T   OLD  0.869323  0.845412
# 43   3     7  Baseline            NoT   OLD  1.098168  0.984395
# 44   3     7     Hconc              T   OLD  1.016560  0.818242
# 45   3     7     Hconc            NoT   OLD  1.521537  0.879831
# 46   3     7      Hcol              T   OLD  0.841602  0.809849
# 47   3     7      Hcol            NoT   OLD  1.014338  0.818960
# 48   3    10  Baseline              T   OLD  1.368966  0.812716
# 49   3    10  Baseline            NoT   OLD  0.162221  0.899764
#
#     correct_trials
# 0               38
# 1               40
# 2               35
# 3               40
# 4               35
# 5               36
# 6               30
# 7               36
# 8               33
# 9               32
# 10              30
# 11              30
# 12              33
# 13              36
# 14              30
# 15              37
# 16              27
# 17              29
# 18              34
# 19              40
# 20              36
# 21              37
# 22              32
# 23              39
# 24              31
# 25              36
# 26              33
# 27              37
# 28              30
# 29              36
# 30              33
# 31              32
# 32              34
# 33              36
# 34              28
# 35              36
# 36              40
# 37              40
# 38              37
# 39              38
# 40              31
# 41              38
# 42              34
# 43              39
# 44              33
# 45              35
# 46              32
# 47              33
# 48              33
# 49              36
#       ID  Nfig      Tipo TargetPresence  Group        RT  Accuracy  \
# 1030  58     5      Hcol              T  YOUNG  0.675898  0.776880
# 1031  58     5      Hcol            NoT  YOUNG  0.206424  0.852805
# 1032  58     7  Baseline              T  YOUNG  0.303818  0.704641
# 1033  58     7  Baseline            NoT  YOUNG  0.616803  0.802724
# 1034  58     7     Hconc              T  YOUNG  0.250550  0.676806
# 1035  58     7     Hconc            NoT  YOUNG  1.532847  0.660731
# 1036  58     7      Hcol              T  YOUNG  0.797659  0.661901
# 1037  58     7      Hcol            NoT  YOUNG  1.035397  0.691095
# 1038  58    10  Baseline              T  YOUNG  0.566010  0.708882
# 1039  58    10  Baseline            NoT  YOUNG  1.348646  0.719080
# 1040  58    10     Hconc              T  YOUNG  0.998599  0.666666
# 1041  58    10     Hconc            NoT  YOUNG  0.999768  0.667716
# 1042  58    10      Hcol              T  YOUNG  0.671887  0.660090
# 1043  58    10      Hcol            NoT  YOUNG  1.123747  0.662287
# 1044  59     5  Baseline              T  YOUNG  0.347203  0.832886
# 1045  59     5  Baseline            NoT  YOUNG  1.005194  0.826310
# 1046  59     5     Hconc              T  YOUNG  0.586605  0.744570
# 1047  59     5     Hconc            NoT  YOUNG  0.751524  0.796508
# 1048  59     5      Hcol              T  YOUNG  1.373476  0.686167
# 1049  59     5      Hcol            NoT  YOUNG  0.776308  0.735033
# 1050  59     7  Baseline              T  YOUNG  0.975684  0.709561
# 1051  59     7  Baseline            NoT  YOUNG  0.548255  0.843465
# 1052  59     7     Hconc              T  YOUNG  1.186770  0.669184
# 1053  59     7     Hconc            NoT  YOUNG  0.933086  0.752913
# 1054  59     7      Hcol              T  YOUNG  1.117189  0.662510
# 1055  59     7      Hcol            NoT  YOUNG  0.287896  0.741057
# 1056  59    10  Baseline              T  YOUNG  0.385613  0.723261
# 1057  59    10  Baseline            NoT  YOUNG  0.779080  0.675435
# 1058  59    10     Hconc              T  YOUNG  0.641382  0.650905
# 1059  59    10     Hconc            NoT  YOUNG  0.959549  0.713662
# 1060  59    10      Hcol              T  YOUNG  1.398208  0.665167
# 1061  59    10      Hcol            NoT  YOUNG  0.669961  0.706323
# 1062  60     5  Baseline              T  YOUNG  0.966987  0.784193
# 1063  60     5  Baseline            NoT  YOUNG  1.167447  0.828757
# 1064  60     5     Hconc              T  YOUNG  0.619974  0.662047
# 1065  60     5     Hconc            NoT  YOUNG  0.500917  0.819200
# 1066  60     5      Hcol              T  YOUNG  1.002421  0.676437
# 1067  60     5      Hcol            NoT  YOUNG  0.168109  0.780743
# 1068  60     7  Baseline              T  YOUNG  0.596776  0.775165
# 1069  60     7  Baseline            NoT  YOUNG  1.073407  0.811177
# 1070  60     7     Hconc              T  YOUNG  0.450948  0.674514
# 1071  60     7     Hconc            NoT  YOUNG  0.935877  0.778942
# 1072  60     7      Hcol              T  YOUNG  0.569279  0.660376
# 1073  60     7      Hcol            NoT  YOUNG  1.010997  0.662131
# 1074  60    10  Baseline              T  YOUNG  0.555173  0.682022
# 1075  60    10  Baseline            NoT  YOUNG  0.428599  0.667891
# 1076  60    10     Hconc              T  YOUNG  0.985796  0.667419
# 1077  60    10     Hconc            NoT  YOUNG  0.845631  0.745297
# 1078  60    10      Hcol              T  YOUNG  0.434199  0.667126
# 1079  60    10      Hcol            NoT  YOUNG  0.778564  0.677169
#
#       correct_trials
# 1030              31
# 1031              34
# 1032              28
# 1033              32
# 1034              27
# 1035              26
# 1036              26
# 1037              28
# 1038              28
# 1039              29
# 1040              27
# 1041              27
# 1042              26
# 1043              26
# 1044              33
# 1045              33
# 1046              30
# 1047              32
# 1048              27
# 1049              29
# 1050              28
# 1051              34
# 1052              27
# 1053              30
# 1054              27
# 1055              30
# 1056              29
# 1057              27
# 1058              26
# 1059              29
# 1060              27
# 1061              28
# 1062              31
# 1063              33
# 1064              26
# 1065              33
# 1066              27
# 1067              31
# 1068              31
# 1069              32
# 1070              27
# 1071              31
# 1072              26
# 1073              26
# 1074              27
# 1075              27
# 1076              27
# 1077              30
# 1078              27
# 1079              27

# %%
# STEP 2. T-test RT

# t-test mean RT OLD vs YOUNG not considering any predictor
rt_old = df_ideal[df_ideal['Group'] == 'OLD']['RT']
rt_young = df_ideal[df_ideal['Group'] == 'YOUNG']['RT']

t_stat, p_value = ttest_ind(rt_old, rt_young)
print(f"t-statistic: {t_stat}, p-value: {p_value}")
# Out:
# t-statistic: 9.615681863361543, p-value: 4.668850392025545e-21

# %%
# STEP 3. visualization of mean RT OLD vs YOUNG not considering any predictor

# calculate mean RT and standard error for YOUNG and OLD
mean_rt_young = df_ideal[df_ideal['Group'] == 'YOUNG']['RT'].mean()
std_err_young = df_ideal[df_ideal['Group'] == 'YOUNG']['RT'].sem()
mean_rt_old = df_ideal[df_ideal['Group'] == 'OLD']['RT'].mean()
std_err_old = df_ideal[df_ideal['Group'] == 'OLD']['RT'].sem() 
print(f"YOUNG mean RT: {mean_rt_young}, YOUNG SE: {std_err_young}")
print(f"OLD mean RT: {mean_rt_old}, OLD SE: {std_err_old} ")

# mean RT for each participant considering all conditions together
mean_rt_young_ID = df_ideal[df_ideal['Group'] == 'YOUNG'].groupby('ID')['RT'].mean()
mean_rt_old_ID = df_ideal[df_ideal['Group'] == 'OLD'].groupby('ID')['RT'].mean()

# create a BAR plot
plt.figure(figsize=(10, 6))
plt.bar(['YOUNG', 'OLD'], [mean_rt_young, mean_rt_old], yerr=[std_err_young, std_err_old], capsize=5, color=['blue', 'violet'], label='Mean RT with SE')

# in order to visualize also single data points, create a jitter for each participant's data point
jitter_y = np.random.normal(loc=0, scale=0.05, size=len(mean_rt_young_ID))
jitter_o = np.random.normal(loc=0, scale=0.05, size=len(mean_rt_old_ID))

# add individual participant RTs as jittered data points
plt.scatter(np.zeros(len(mean_rt_young_ID)) + jitter_y, mean_rt_young_ID, color='pink', alpha=0.5, label='Individual RT (YOUNG)')
plt.scatter(np.ones(len(mean_rt_old_ID)) + jitter_o, mean_rt_old_ID, color='lightblue', alpha=0.5, label='Individual RT (OLD)')

# following the t-test results, add significance star if any
if p_value < 0.001:
    sig = '***'  # Highly significant
elif p_value < 0.01:
    sig = '**'  # Very significant
elif p_value < 0.05:
    sig = '*'  # Significant
else:
    sig = 'n.s.'  # Not significant
    
# position of the star or "n.s." is midway of the bars, slightly above the highest error bar
plt.text(0.5, max(mean_rt_young + std_err_young, mean_rt_old + std_err_old) + 0.15, sig, ha='center', va='bottom', color='black', fontsize=20)

# add line connecting the bars
y_max = max(mean_rt_young + std_err_young, mean_rt_old + std_err_old) + 0.15
plt.plot([0, 1], [y_max, y_max], color='black')

plt.xlabel('Group')
plt.ylabel('Mean Reaction Time (RT)')
plt.title('Mean Reaction Time (RT) Comparison between YOUNG and OLD')
plt.ylim(0.5, 1.4)  # Set y-axis range
plt.xticks([0, 1], ['YOUNG', 'OLD'])
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# create a BOXPLOT
plt.figure(figsize=(10, 6))
data = [mean_rt_young_ID, mean_rt_old_ID]
plt.boxplot(data, labels=['YOUNG', 'OLD'], patch_artist=True, boxprops=dict(facecolor='lightgrey', color='black', alpha=0.5), medianprops=dict(color='red'))

# In order to visualize also single data points, create a jitter for each participant's data point
jitter_y = np.random.normal(loc=1, scale=0.05, size=len(mean_rt_young_ID))
jitter_o = np.random.normal(loc=2, scale=0.05, size=len(mean_rt_old_ID))

# Add individual participant RTs as jittered data points
plt.scatter(jitter_y, mean_rt_young_ID, color='pink', alpha=0.5, label='Individual RT (YOUNG)')
plt.scatter(jitter_o, mean_rt_old_ID, color='lightblue', alpha=0.5, label='Individual RT (OLD)')

# Following the t-test results, add significance star if any
if p_value < 0.001:
    sig = '***'  # Highly significant
elif p_value < 0.01:
    sig = '**'  # Very significant
elif p_value < 0.05:
    sig = '*'  # Significant
else:
    sig = 'n.s.'  # Not significant

# Position of the star or "n.s." is midway of the boxes, slightly above the highest box
plt.text(1.5, max(mean_rt_young + std_err_young, mean_rt_old + std_err_old) + 0.15, sig, ha='center', va='bottom', color='black', fontsize=20)

# Add line connecting the boxes
y_max = max(mean_rt_young + std_err_young, mean_rt_old + std_err_old) + 0.15
plt.plot([1, 2], [y_max, y_max], color='black')

plt.xlabel('Group')
plt.ylabel('Mean Reaction Time (RT)')
plt.title('Mean Reaction Time (RT) Comparison between YOUNG and OLD')
plt.ylim(0.5, 1.4)  # Set y-axis range
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()
# Out:
# YOUNG mean RT: 0.7959586846934951, YOUNG SE: 0.013481043327409186
# OLD mean RT: 0.983445726703313, OLD SE: 0.014086710383010986

# %%
# STEP 4. checking assumptions for parametric methods

# Assumption 1: Normality of the residuals
shapiro_test_rt = stats.shapiro(df_ideal['RT'])
print(f"Shapiro-Wilk test for RT: statistic = {shapiro_test_rt.statistic}, p-value = {shapiro_test_rt.pvalue}")

# KIND AND CURIOUS QUESTION FOR WHO IS CURRENTLY LOOKING AT MY CODE:
# HOW DO I MAKE IT POSSIBLE FOR THE RESIDUALS OF THE MODEL OF MY IDEAL DATA TO FOLLOW A NORMAL DISTRIBUTION?

# MOREOVER, IN R I WOULD USE THE Aligned Rank Transform (ART) AS A NON-PARAMETRIC TECHNIQUE USED FOR FACTORIAL DATA ANALYSIS THROUGH THE PACKAGE ARTool BUT I DIDN'T FIND SOMETHING SIMILAR FOR PYTHON
# WHAT SHOULD BE DONE IN MY CASE THAN?

# Assumption 2: Homogeneity of variance
levene_test = stats.levene(df_ideal['RT'][df_ideal['Group'] == 'YOUNG'],
                            df_ideal['RT'][df_ideal['Group'] == 'OLD'])
print(f"Levene's test statistic: {levene_test.statistic}, p-value: {levene_test.pvalue}")
# Out:
# Shapiro-Wilk test for RT: statistic = 0.9955830574035645, p-value = 0.003271837253123522
# Levene's test statistic: 0.057849848046657985, p-value: 0.8099729286953744

# %%
# STEP 5. ANOVA (or non-parametric test)

# create a formula for the ANOVA
formula = 'RT ~ C(Group) + C(Nfig) + C(Tipo) + C(TargetPresence) + C(Group):C(Nfig) + C(Group):C(Tipo) + C(Group):C(TargetPresence) + C(Group):C(Nfig):C(Tipo) + C(Group):C(Nfig):C(TargetPresence) + C(Group):C(Tipo):C(TargetPresence)'

model = ols(formula, df_ideal).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

print(anova_table)
# Out:
#                                         sum_sq      df          F  \
# C(Group)                              9.490876     1.0  99.280508
# C(Nfig)                               1.746685     2.0   9.135710
# C(Tipo)                               3.320669     2.0  17.368138
# C(TargetPresence)                     1.962202     1.0  20.525862
# C(Group):C(Nfig)                      0.253308     2.0   1.324882
# C(Group):C(Tipo)                      0.014041     2.0   0.073439
# C(Group):C(TargetPresence)            0.000020     1.0   0.000208
# C(Group):C(Nfig):C(Tipo)              1.041019     8.0   1.361214
# C(Group):C(Nfig):C(TargetPresence)    0.414063     4.0   1.082840
# C(Group):C(Tipo):C(TargetPresence)    1.333833     4.0   3.488183
# Residual                            100.567587  1052.0        NaN
#
#                                           PR(>F)
# C(Group)                            2.078353e-22
# C(Nfig)                             1.165394e-04
# C(Tipo)                             3.792876e-08
# C(TargetPresence)                   6.556212e-06
# C(Group):C(Nfig)                    2.662774e-01
# C(Group):C(Tipo)                    9.291980e-01
# C(Group):C(TargetPresence)          9.885090e-01
# C(Group):C(Nfig):C(Tipo)            2.094911e-01
# C(Group):C(Nfig):C(TargetPresence)  3.636095e-01
# C(Group):C(Tipo):C(TargetPresence)  7.707680e-03
# Residual                                     NaN

# %%
# STEP 6. POST-HOC tests

# perform post-hoc test for 'Group'
posthoc_group = pairwise_tukeyhsd(df_ideal['RT'], df_ideal['Group'], alpha=0.05)
print(posthoc_group)

# perform post-hoc test for 'Nfig'
posthoc_nfig = pairwise_tukeyhsd(df_ideal['RT'], df_ideal['Nfig'], alpha=0.05)
print(posthoc_nfig)

# perform post-hoc test for 'Tipo'
posthoc_tipo = pairwise_tukeyhsd(df_ideal['RT'], df_ideal['Tipo'], alpha=0.05)
print(posthoc_tipo)

# perform post-hoc test for 'TargetPresence'
posthoc_target_presence = pairwise_tukeyhsd(df_ideal['RT'], df_ideal['TargetPresence'], alpha=0.05)
print(posthoc_target_presence)

# create interaction columns
df_ideal['Group_Nfig'] = df_ideal['Group'] + "_" + df_ideal['Nfig'].astype(str)
df_ideal['Group_Tipo'] = df_ideal['Group'] + "_" + df_ideal['Tipo']
df_ideal['Group_TargetPresence'] = df_ideal['Group'] + "_" + df_ideal['TargetPresence']
df_ideal['Group_Nfig_Tipo'] = df_ideal['Group'] + "_" + df_ideal['Nfig'].astype(str) + "_" + df_ideal['Tipo']
df_ideal['Group_Nfig_TargetPresence'] = df_ideal['Group'] + "_" + df_ideal['Nfig'].astype(str) + "_" + df_ideal['TargetPresence']
df_ideal['Group_Tipo_TargetPresence'] = df_ideal['Group'] + "_" + df_ideal['Tipo'] + "_" + df_ideal['TargetPresence']

# post-hoc test for 'Group:Nfig' interaction
posthoc_group_nfig = pairwise_tukeyhsd(df_ideal['RT'], df_ideal['Group_Nfig'], alpha=0.05)
print(posthoc_group_nfig)

# post-hoc test for 'Group:Tipo' interaction
posthoc_group_tipo = pairwise_tukeyhsd(df_ideal['RT'], df_ideal['Group_Tipo'], alpha=0.05)
print(posthoc_group_tipo)

# post-hoc test for 'Group:TargetPresence' interaction
posthoc_group_target_presence = pairwise_tukeyhsd(df_ideal['RT'], df_ideal['Group_TargetPresence'], alpha=0.05)
print(posthoc_group_target_presence)

# post-hoc test for 'Group:Nfig:Tipo' interaction
posthoc_group_nfig_tipo = pairwise_tukeyhsd(df_ideal['RT'], df_ideal['Group_Nfig_Tipo'], alpha=0.05)
print(posthoc_group_nfig_tipo)

# post-hoc test for 'Group:Nfig:TargetPresence' interaction
posthoc_group_nfig_target_presence = pairwise_tukeyhsd(df_ideal['RT'], df_ideal['Group_Nfig_TargetPresence'], alpha=0.05)
print(posthoc_group_nfig_target_presence)

# post-hoc test for 'Group:Tipo:TargetPresence' interaction
posthoc_group_tipo_target_presence = pairwise_tukeyhsd(df_ideal['RT'], df_ideal['Group_Tipo_TargetPresence'], alpha=0.05)
print(posthoc_group_tipo_target_presence)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#    OLD  YOUNG  -0.1875   0.0 -0.2257 -0.1492   True
# ---------------------------------------------------
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#      5      7   0.0342 0.3488 -0.0238 0.0922  False
#      5     10   0.0971 0.0003  0.0391 0.1551   True
#      7     10   0.0629 0.0298  0.0049 0.1209   True
# ---------------------------------------------------
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
#  group1  group2 meandiff p-adj   lower  upper  reject
# -----------------------------------------------------
# Baseline   Hcol   0.0983 0.0002  0.0407  0.156   True
# Baseline  Hconc   0.1303    0.0  0.0727 0.1879   True
#     Hcol  Hconc    0.032 0.3941 -0.0256 0.0896  False
# -----------------------------------------------------
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#    NoT      T  -0.0852   0.0 -0.1248 -0.0457   True
# ---------------------------------------------------
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
#  group1   group2  meandiff p-adj   lower   upper  reject
# --------------------------------------------------------
#   OLD_10    OLD_5  -0.1227 0.0036 -0.2184  -0.027   True
#   OLD_10    OLD_7  -0.0519 0.6334 -0.1476  0.0438  False
#   OLD_10 YOUNG_10  -0.1972    0.0 -0.2929 -0.1015   True
#   OLD_10  YOUNG_5  -0.2688    0.0 -0.3645  -0.173   True
#   OLD_10  YOUNG_7  -0.2711    0.0 -0.3668 -0.1753   True
#    OLD_5    OLD_7   0.0708 0.2819 -0.0249  0.1665  False
#    OLD_5 YOUNG_10  -0.0745  0.228 -0.1702  0.0212  False
#    OLD_5  YOUNG_5  -0.1461 0.0002 -0.2418 -0.0504   True
#    OLD_5  YOUNG_7  -0.1484 0.0002 -0.2441 -0.0527   True
#    OLD_7 YOUNG_10  -0.1453 0.0002  -0.241 -0.0496   True
#    OLD_7  YOUNG_5  -0.2169    0.0 -0.3126 -0.1211   True
#    OLD_7  YOUNG_7  -0.2192    0.0 -0.3149 -0.1235   True
# YOUNG_10  YOUNG_5  -0.0715 0.2706 -0.1673  0.0242  False
# YOUNG_10  YOUNG_7  -0.0739 0.2372 -0.1696  0.0219  False
#  YOUNG_5  YOUNG_7  -0.0023    1.0  -0.098  0.0934  False
# --------------------------------------------------------
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================================
#     group1         group2     meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------------
#   OLD_Baseline       OLD_Hcol   0.0897 0.0777 -0.0054  0.1848  False
#   OLD_Baseline      OLD_Hconc   0.1275 0.0019  0.0324  0.2227   True
#   OLD_Baseline YOUNG_Baseline  -0.1951    0.0 -0.2902    -0.1   True
#   OLD_Baseline     YOUNG_Hcol  -0.0881 0.0878 -0.1832   0.007  False
#   OLD_Baseline    YOUNG_Hconc   -0.062 0.4268 -0.1571  0.0331  False
#       OLD_Hcol      OLD_Hconc   0.0379 0.8663 -0.0573   0.133  False
#       OLD_Hcol YOUNG_Baseline  -0.2848    0.0 -0.3799 -0.1897   True
#       OLD_Hcol     YOUNG_Hcol  -0.1778    0.0 -0.2729 -0.0827   True
#       OLD_Hcol    YOUNG_Hconc  -0.1517 0.0001 -0.2468 -0.0566   True
#      OLD_Hconc YOUNG_Baseline  -0.3226    0.0 -0.4178 -0.2275   True
#      OLD_Hconc     YOUNG_Hcol  -0.2157    0.0 -0.3108 -0.1205   True
#      OLD_Hconc    YOUNG_Hconc  -0.1896    0.0 -0.2847 -0.0944   True
# YOUNG_Baseline     YOUNG_Hcol    0.107 0.0171  0.0119  0.2021   True
# YOUNG_Baseline    YOUNG_Hconc   0.1331  0.001  0.0379  0.2282   True
#     YOUNG_Hcol    YOUNG_Hconc   0.0261 0.9704  -0.069  0.1212  False
# --------------------------------------------------------------------
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================
#   group1    group2  meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------
#   OLD_NoT     OLD_T  -0.0855 0.0098 -0.1559 -0.0151   True
#   OLD_NoT YOUNG_NoT  -0.1878    0.0 -0.2581 -0.1174   True
#   OLD_NoT   YOUNG_T  -0.2727    0.0 -0.3431 -0.2024   True
#     OLD_T YOUNG_NoT  -0.1022 0.0011 -0.1726 -0.0319   True
#     OLD_T   YOUNG_T  -0.1872    0.0 -0.2576 -0.1168   True
# YOUNG_NoT   YOUNG_T   -0.085 0.0105 -0.1554 -0.0146   True
# ----------------------------------------------------------
#            Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================================
#       group1            group2      meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------------------
#   OLD_10_Baseline       OLD_10_Hcol   0.2004 0.0491  0.0003  0.4005   True
#   OLD_10_Baseline      OLD_10_Hconc   0.2466 0.0024  0.0465  0.4467   True
#   OLD_10_Baseline    OLD_5_Baseline  -0.0025    1.0 -0.2026  0.1976  False
#   OLD_10_Baseline        OLD_5_Hcol   0.0453    1.0 -0.1547  0.2454  False
#   OLD_10_Baseline       OLD_5_Hconc   0.0361    1.0  -0.164  0.2362  False
#   OLD_10_Baseline    OLD_7_Baseline   0.0577 0.9999 -0.1424  0.2578  False
#   OLD_10_Baseline        OLD_7_Hcol   0.0785 0.9965 -0.1216  0.2786  False
#   OLD_10_Baseline       OLD_7_Hconc   0.1551 0.3735  -0.045  0.3552  False
#   OLD_10_Baseline YOUNG_10_Baseline  -0.1349 0.6403  -0.335  0.0652  False
#   OLD_10_Baseline     YOUNG_10_Hcol  -0.0359    1.0 -0.2359  0.1642  False
#   OLD_10_Baseline    YOUNG_10_Hconc   0.0261    1.0  -0.174  0.2262  False
#   OLD_10_Baseline  YOUNG_5_Baseline  -0.2105 0.0273 -0.4106 -0.0104   True
#   OLD_10_Baseline      YOUNG_5_Hcol  -0.0897 0.9849 -0.2898  0.1104  False
#   OLD_10_Baseline     YOUNG_5_Hconc   -0.059 0.9999 -0.2591  0.1411  False
#   OLD_10_Baseline  YOUNG_7_Baseline  -0.1847 0.1119 -0.3848  0.0154  False
#   OLD_10_Baseline      YOUNG_7_Hcol  -0.0835  0.993 -0.2836  0.1166  False
#   OLD_10_Baseline     YOUNG_7_Hconc   -0.098 0.9641 -0.2981  0.1021  False
#       OLD_10_Hcol      OLD_10_Hconc   0.0462    1.0 -0.1539  0.2463  False
#       OLD_10_Hcol    OLD_5_Baseline  -0.2029 0.0427  -0.403 -0.0028   True
#       OLD_10_Hcol        OLD_5_Hcol  -0.1551 0.3741 -0.3552   0.045  False
#       OLD_10_Hcol       OLD_5_Hconc  -0.1643 0.2704 -0.3644  0.0358  False
#       OLD_10_Hcol    OLD_7_Baseline  -0.1427  0.535 -0.3428  0.0574  False
#       OLD_10_Hcol        OLD_7_Hcol  -0.1219 0.7979  -0.322  0.0782  False
#       OLD_10_Hcol       OLD_7_Hconc  -0.0453    1.0 -0.2454  0.1548  False
#       OLD_10_Hcol YOUNG_10_Baseline  -0.3353    0.0 -0.5354 -0.1352   True
#       OLD_10_Hcol     YOUNG_10_Hcol  -0.2363  0.005 -0.4364 -0.0362   True
#       OLD_10_Hcol    YOUNG_10_Hconc  -0.1743 0.1803 -0.3744  0.0258  False
#       OLD_10_Hcol  YOUNG_5_Baseline  -0.4109    0.0  -0.611 -0.2108   True
#       OLD_10_Hcol      YOUNG_5_Hcol  -0.2902 0.0001 -0.4902 -0.0901   True
#       OLD_10_Hcol     YOUNG_5_Hconc  -0.2594 0.0009 -0.4595 -0.0593   True
#       OLD_10_Hcol  YOUNG_7_Baseline  -0.3851    0.0 -0.5852  -0.185   True
#       OLD_10_Hcol      YOUNG_7_Hcol  -0.2839 0.0001  -0.484 -0.0838   True
#       OLD_10_Hcol     YOUNG_7_Hconc  -0.2984    0.0 -0.4985 -0.0983   True
#      OLD_10_Hconc    OLD_5_Baseline  -0.2491  0.002 -0.4492  -0.049   True
#      OLD_10_Hconc        OLD_5_Hcol  -0.2013 0.0468 -0.4014 -0.0012   True
#      OLD_10_Hconc       OLD_5_Hconc  -0.2105 0.0273 -0.4106 -0.0104   True
#      OLD_10_Hconc    OLD_7_Baseline  -0.1889 0.0907  -0.389  0.0112  False
#      OLD_10_Hconc        OLD_7_Hcol  -0.1681 0.2335 -0.3682   0.032  False
#      OLD_10_Hconc       OLD_7_Hconc  -0.0915 0.9816 -0.2916  0.1086  False
#      OLD_10_Hconc YOUNG_10_Baseline  -0.3815    0.0 -0.5816 -0.1814   True
#      OLD_10_Hconc     YOUNG_10_Hcol  -0.2825 0.0001 -0.4826 -0.0824   True
#      OLD_10_Hconc    YOUNG_10_Hconc  -0.2205 0.0146 -0.4206 -0.0204   True
#      OLD_10_Hconc  YOUNG_5_Baseline  -0.4571    0.0 -0.6572  -0.257   True
#      OLD_10_Hconc      YOUNG_5_Hcol  -0.3363    0.0 -0.5364 -0.1363   True
#      OLD_10_Hconc     YOUNG_5_Hconc  -0.3056    0.0 -0.5057 -0.1055   True
#      OLD_10_Hconc  YOUNG_7_Baseline  -0.4313    0.0 -0.6314 -0.2312   True
#      OLD_10_Hconc      YOUNG_7_Hcol  -0.3301    0.0 -0.5302   -0.13   True
#      OLD_10_Hconc     YOUNG_7_Hconc  -0.3446    0.0 -0.5447 -0.1445   True
#    OLD_5_Baseline        OLD_5_Hcol   0.0478    1.0 -0.1523  0.2479  False
#    OLD_5_Baseline       OLD_5_Hconc   0.0386    1.0 -0.1615  0.2387  False
#    OLD_5_Baseline    OLD_7_Baseline   0.0602 0.9999 -0.1399  0.2603  False
#    OLD_5_Baseline        OLD_7_Hcol    0.081  0.995 -0.1191  0.2811  False
#    OLD_5_Baseline       OLD_7_Hconc   0.1576 0.3439 -0.0425  0.3577  False
#    OLD_5_Baseline YOUNG_10_Baseline  -0.1324 0.6727 -0.3325  0.0677  False
#    OLD_5_Baseline     YOUNG_10_Hcol  -0.0334    1.0 -0.2335  0.1667  False
#    OLD_5_Baseline    YOUNG_10_Hconc   0.0286    1.0 -0.1715  0.2287  False
#    OLD_5_Baseline  YOUNG_5_Baseline   -0.208 0.0317 -0.4081 -0.0079   True
#    OLD_5_Baseline      YOUNG_5_Hcol  -0.0873 0.9888 -0.2873  0.1128  False
#    OLD_5_Baseline     YOUNG_5_Hconc  -0.0565    1.0 -0.2566  0.1436  False
#    OLD_5_Baseline  YOUNG_7_Baseline  -0.1822  0.126 -0.3823  0.0179  False
#    OLD_5_Baseline      YOUNG_7_Hcol   -0.081  0.995 -0.2811  0.1191  False
#    OLD_5_Baseline     YOUNG_7_Hconc  -0.0955 0.9719 -0.2956  0.1046  False
#        OLD_5_Hcol       OLD_5_Hconc  -0.0092    1.0 -0.2093  0.1909  False
#        OLD_5_Hcol    OLD_7_Baseline   0.0124    1.0 -0.1877  0.2125  False
#        OLD_5_Hcol        OLD_7_Hcol   0.0332    1.0 -0.1669  0.2333  False
#        OLD_5_Hcol       OLD_7_Hconc   0.1098 0.9043 -0.0903  0.3099  False
#        OLD_5_Hcol YOUNG_10_Baseline  -0.1802 0.1382 -0.3803  0.0199  False
#        OLD_5_Hcol     YOUNG_10_Hcol  -0.0812 0.9949 -0.2813  0.1189  False
#        OLD_5_Hcol    YOUNG_10_Hconc  -0.0192    1.0 -0.2193  0.1809  False
#        OLD_5_Hcol  YOUNG_5_Baseline  -0.2558 0.0012 -0.4559 -0.0557   True
#        OLD_5_Hcol      YOUNG_5_Hcol  -0.1351 0.6378 -0.3352   0.065  False
#        OLD_5_Hcol     YOUNG_5_Hconc  -0.1043  0.937 -0.3044  0.0957  False
#        OLD_5_Hcol  YOUNG_7_Baseline    -0.23 0.0078 -0.4301 -0.0299   True
#        OLD_5_Hcol      YOUNG_7_Hcol  -0.1289 0.7176 -0.3289  0.0712  False
#        OLD_5_Hcol     YOUNG_7_Hconc  -0.1433 0.5269 -0.3434  0.0568  False
#       OLD_5_Hconc    OLD_7_Baseline   0.0216    1.0 -0.1785  0.2217  False
#       OLD_5_Hconc        OLD_7_Hcol   0.0424    1.0 -0.1577  0.2425  False
#       OLD_5_Hconc       OLD_7_Hconc    0.119 0.8273 -0.0811  0.3191  False
#       OLD_5_Hconc YOUNG_10_Baseline   -0.171 0.2072 -0.3711  0.0291  False
#       OLD_5_Hconc     YOUNG_10_Hcol   -0.072 0.9988 -0.2721  0.1281  False
#       OLD_5_Hconc    YOUNG_10_Hconc    -0.01    1.0 -0.2101  0.1901  False
#       OLD_5_Hconc  YOUNG_5_Baseline  -0.2466 0.0024 -0.4467 -0.0465   True
#       OLD_5_Hconc      YOUNG_5_Hcol  -0.1259 0.7536 -0.3259  0.0742  False
#       OLD_5_Hconc     YOUNG_5_Hconc  -0.0951 0.9729 -0.2952   0.105  False
#       OLD_5_Hconc  YOUNG_7_Baseline  -0.2208 0.0143 -0.4209 -0.0207   True
#       OLD_5_Hconc      YOUNG_7_Hcol  -0.1196 0.8211 -0.3197  0.0805  False
#       OLD_5_Hconc     YOUNG_7_Hconc  -0.1341 0.6507 -0.3342   0.066  False
#    OLD_7_Baseline        OLD_7_Hcol   0.0208    1.0 -0.1793  0.2209  False
#    OLD_7_Baseline       OLD_7_Hconc   0.0974  0.966 -0.1027  0.2975  False
#    OLD_7_Baseline YOUNG_10_Baseline  -0.1926  0.075 -0.3927  0.0075  False
#    OLD_7_Baseline     YOUNG_10_Hcol  -0.0936  0.977 -0.2936  0.1065  False
#    OLD_7_Baseline    YOUNG_10_Hconc  -0.0316    1.0 -0.2317  0.1685  False
#    OLD_7_Baseline  YOUNG_5_Baseline  -0.2682 0.0004 -0.4683 -0.0681   True
#    OLD_7_Baseline      YOUNG_5_Hcol  -0.1474 0.4716 -0.3475  0.0526  False
#    OLD_7_Baseline     YOUNG_5_Hconc  -0.1167 0.8491 -0.3168  0.0834  False
#    OLD_7_Baseline  YOUNG_7_Baseline  -0.2424 0.0033 -0.4425 -0.0423   True
#    OLD_7_Baseline      YOUNG_7_Hcol  -0.1412 0.5552 -0.3413  0.0589  False
#    OLD_7_Baseline     YOUNG_7_Hconc  -0.1557 0.3668 -0.3558  0.0444  False
#        OLD_7_Hcol       OLD_7_Hconc   0.0766 0.9974 -0.1235  0.2767  False
#        OLD_7_Hcol YOUNG_10_Baseline  -0.2134 0.0228 -0.4135 -0.0133   True
#        OLD_7_Hcol     YOUNG_10_Hcol  -0.1144 0.8693 -0.3145  0.0857  False
#        OLD_7_Hcol    YOUNG_10_Hconc  -0.0524    1.0 -0.2525  0.1477  False
#        OLD_7_Hcol  YOUNG_5_Baseline   -0.289 0.0001 -0.4891 -0.0889   True
#        OLD_7_Hcol      YOUNG_5_Hcol  -0.1683 0.2317 -0.3684  0.0318  False
#        OLD_7_Hcol     YOUNG_5_Hconc  -0.1375  0.605 -0.3376  0.0626  False
#        OLD_7_Hcol  YOUNG_7_Baseline  -0.2632 0.0007 -0.4633 -0.0631   True
#        OLD_7_Hcol      YOUNG_7_Hcol  -0.1621  0.294 -0.3621   0.038  False
#        OLD_7_Hcol     YOUNG_7_Hconc  -0.1765 0.1635 -0.3766  0.0236  False
#       OLD_7_Hconc YOUNG_10_Baseline    -0.29 0.0001 -0.4901 -0.0899   True
#       OLD_7_Hconc     YOUNG_10_Hcol   -0.191 0.0816 -0.3911  0.0091  False
#       OLD_7_Hconc    YOUNG_10_Hconc   -0.129 0.7158 -0.3291  0.0711  False
#       OLD_7_Hconc  YOUNG_5_Baseline  -0.3656    0.0 -0.5657 -0.1655   True
#       OLD_7_Hconc      YOUNG_5_Hcol  -0.2449 0.0027  -0.445 -0.0448   True
#       OLD_7_Hconc     YOUNG_5_Hconc  -0.2141 0.0219 -0.4142  -0.014   True
#       OLD_7_Hconc  YOUNG_7_Baseline  -0.3398    0.0 -0.5399 -0.1397   True
#       OLD_7_Hconc      YOUNG_7_Hcol  -0.2386 0.0043 -0.4387 -0.0386   True
#       OLD_7_Hconc     YOUNG_7_Hconc  -0.2531 0.0015 -0.4532  -0.053   True
# YOUNG_10_Baseline     YOUNG_10_Hcol    0.099 0.9604 -0.1011  0.2991  False
# YOUNG_10_Baseline    YOUNG_10_Hconc    0.161 0.3051 -0.0391  0.3611  False
# YOUNG_10_Baseline  YOUNG_5_Baseline  -0.0756 0.9978 -0.2757  0.1245  False
# YOUNG_10_Baseline      YOUNG_5_Hcol   0.0452    1.0 -0.1549  0.2452  False
# YOUNG_10_Baseline     YOUNG_5_Hconc   0.0759 0.9977 -0.1242   0.276  False
# YOUNG_10_Baseline  YOUNG_7_Baseline  -0.0498    1.0 -0.2499  0.1503  False
# YOUNG_10_Baseline      YOUNG_7_Hcol   0.0514    1.0 -0.1487  0.2515  False
# YOUNG_10_Baseline     YOUNG_7_Hconc   0.0369    1.0 -0.1632   0.237  False
#     YOUNG_10_Hcol    YOUNG_10_Hconc    0.062 0.9998 -0.1381  0.2621  False
#     YOUNG_10_Hcol  YOUNG_5_Baseline  -0.1746 0.1776 -0.3747  0.0255  False
#     YOUNG_10_Hcol      YOUNG_5_Hcol  -0.0539    1.0  -0.254  0.1462  False
#     YOUNG_10_Hcol     YOUNG_5_Hconc  -0.0231    1.0 -0.2232  0.1769  False
#     YOUNG_10_Hcol  YOUNG_7_Baseline  -0.1488 0.4535 -0.3489  0.0513  False
#     YOUNG_10_Hcol      YOUNG_7_Hcol  -0.0477    1.0 -0.2477  0.1524  False
#     YOUNG_10_Hcol     YOUNG_7_Hconc  -0.0621 0.9998 -0.2622   0.138  False
#    YOUNG_10_Hconc  YOUNG_5_Baseline  -0.2366 0.0049 -0.4367 -0.0365   True
#    YOUNG_10_Hconc      YOUNG_5_Hcol  -0.1159 0.8566  -0.316  0.0842  False
#    YOUNG_10_Hconc     YOUNG_5_Hconc  -0.0851 0.9914 -0.2852   0.115  False
#    YOUNG_10_Hconc  YOUNG_7_Baseline  -0.2108 0.0268 -0.4109 -0.0107   True
#    YOUNG_10_Hconc      YOUNG_7_Hcol  -0.1096 0.9053 -0.3097  0.0904  False
#    YOUNG_10_Hconc     YOUNG_7_Hconc  -0.1241 0.7735 -0.3242   0.076  False
#  YOUNG_5_Baseline      YOUNG_5_Hcol   0.1208 0.8097 -0.0793  0.3208  False
#  YOUNG_5_Baseline     YOUNG_5_Hconc   0.1515 0.4189 -0.0486  0.3516  False
#  YOUNG_5_Baseline  YOUNG_7_Baseline   0.0258    1.0 -0.1743  0.2259  False
#  YOUNG_5_Baseline      YOUNG_7_Hcol    0.127 0.7403 -0.0731  0.3271  False
#  YOUNG_5_Baseline     YOUNG_7_Hconc   0.1125 0.8844 -0.0876  0.3126  False
#      YOUNG_5_Hcol     YOUNG_5_Hconc   0.0307    1.0 -0.1694  0.2308  False
#      YOUNG_5_Hcol  YOUNG_7_Baseline  -0.0949 0.9734  -0.295  0.1052  False
#      YOUNG_5_Hcol      YOUNG_7_Hcol   0.0062    1.0 -0.1939  0.2063  False
#      YOUNG_5_Hcol     YOUNG_7_Hconc  -0.0082    1.0 -0.2083  0.1918  False
#     YOUNG_5_Hconc  YOUNG_7_Baseline  -0.1257 0.7557 -0.3258  0.0744  False
#     YOUNG_5_Hconc      YOUNG_7_Hcol  -0.0245    1.0 -0.2246  0.1756  False
#     YOUNG_5_Hconc     YOUNG_7_Hconc   -0.039    1.0 -0.2391  0.1611  False
#  YOUNG_7_Baseline      YOUNG_7_Hcol   0.1012  0.952 -0.0989  0.3012  False
#  YOUNG_7_Baseline     YOUNG_7_Hconc   0.0867 0.9895 -0.1134  0.2868  False
#      YOUNG_7_Hcol     YOUNG_7_Hconc  -0.0145    1.0 -0.2146  0.1856  False
# --------------------------------------------------------------------------
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#   OLD_10_NoT     OLD_10_T  -0.0956  0.671 -0.2496  0.0584  False
#   OLD_10_NoT    OLD_5_NoT  -0.1031 0.5555 -0.2571  0.0509  False
#   OLD_10_NoT      OLD_5_T  -0.2379    0.0 -0.3919 -0.0838   True
#   OLD_10_NoT    OLD_7_NoT  -0.0866  0.795 -0.2406  0.0675  False
#   OLD_10_NoT      OLD_7_T  -0.1128 0.4079 -0.2668  0.0412  False
#   OLD_10_NoT YOUNG_10_NoT  -0.1849 0.0051 -0.3389 -0.0309   True
#   OLD_10_NoT   YOUNG_10_T  -0.3051    0.0 -0.4591 -0.1511   True
#   OLD_10_NoT  YOUNG_5_NoT  -0.2956    0.0 -0.4496 -0.1416   True
#   OLD_10_NoT    YOUNG_5_T  -0.3375    0.0 -0.4915 -0.1835   True
#   OLD_10_NoT  YOUNG_7_NoT  -0.2725    0.0 -0.4265 -0.1184   True
#   OLD_10_NoT    YOUNG_7_T  -0.3653    0.0 -0.5193 -0.2112   True
#     OLD_10_T    OLD_5_NoT  -0.0075    1.0 -0.1615  0.1465  False
#     OLD_10_T      OLD_5_T  -0.1423 0.1026 -0.2963  0.0118  False
#     OLD_10_T    OLD_7_NoT    0.009    1.0  -0.145   0.163  False
#     OLD_10_T      OLD_7_T  -0.0172    1.0 -0.1712  0.1368  False
#     OLD_10_T YOUNG_10_NoT  -0.0893 0.7598 -0.2433  0.0647  False
#     OLD_10_T   YOUNG_10_T  -0.2095 0.0006 -0.3636 -0.0555   True
#     OLD_10_T  YOUNG_5_NoT     -0.2 0.0014  -0.354  -0.046   True
#     OLD_10_T    YOUNG_5_T  -0.2419    0.0 -0.3959 -0.0879   True
#     OLD_10_T  YOUNG_7_NoT  -0.1769 0.0097 -0.3309 -0.0229   True
#     OLD_10_T    YOUNG_7_T  -0.2697    0.0 -0.4237 -0.1157   True
#    OLD_5_NoT      OLD_5_T  -0.1348 0.1549 -0.2888  0.0193  False
#    OLD_5_NoT    OLD_7_NoT   0.0165    1.0 -0.1375  0.1706  False
#    OLD_5_NoT      OLD_7_T  -0.0097    1.0 -0.1637  0.1443  False
#    OLD_5_NoT YOUNG_10_NoT  -0.0818 0.8496 -0.2358  0.0722  False
#    OLD_5_NoT   YOUNG_10_T   -0.202 0.0011  -0.356  -0.048   True
#    OLD_5_NoT  YOUNG_5_NoT  -0.1925 0.0027 -0.3465 -0.0385   True
#    OLD_5_NoT    YOUNG_5_T  -0.2344    0.0 -0.3884 -0.0804   True
#    OLD_5_NoT  YOUNG_7_NoT  -0.1694 0.0172 -0.3234 -0.0153   True
#    OLD_5_NoT    YOUNG_7_T  -0.2622    0.0 -0.4162 -0.1081   True
#      OLD_5_T    OLD_7_NoT   0.1513 0.0596 -0.0027  0.3053  False
#      OLD_5_T      OLD_7_T   0.1251 0.2483  -0.029  0.2791  False
#      OLD_5_T YOUNG_10_NoT    0.053 0.9935 -0.1011   0.207  False
#      OLD_5_T   YOUNG_10_T  -0.0673 0.9574 -0.2213  0.0868  False
#      OLD_5_T  YOUNG_5_NoT  -0.0577 0.9867 -0.2118  0.0963  False
#      OLD_5_T    YOUNG_5_T  -0.0996 0.6093 -0.2537  0.0544  False
#      OLD_5_T  YOUNG_7_NoT  -0.0346 0.9999 -0.1886  0.1194  False
#      OLD_5_T    YOUNG_7_T  -0.1274 0.2229 -0.2814  0.0266  False
#    OLD_7_NoT      OLD_7_T  -0.0262    1.0 -0.1802  0.1278  False
#    OLD_7_NoT YOUNG_10_NoT  -0.0983 0.6295 -0.2523  0.0557  False
#    OLD_7_NoT   YOUNG_10_T  -0.2186 0.0002 -0.3726 -0.0645   True
#    OLD_7_NoT  YOUNG_5_NoT   -0.209 0.0006 -0.3631  -0.055   True
#    OLD_7_NoT    YOUNG_5_T  -0.2509    0.0 -0.4049 -0.0969   True
#    OLD_7_NoT  YOUNG_7_NoT  -0.1859 0.0047 -0.3399 -0.0319   True
#    OLD_7_NoT    YOUNG_7_T  -0.2787    0.0 -0.4327 -0.1247   True
#      OLD_7_T YOUNG_10_NoT  -0.0721 0.9312 -0.2261  0.0819  False
#      OLD_7_T   YOUNG_10_T  -0.1923 0.0027 -0.3464 -0.0383   True
#      OLD_7_T  YOUNG_5_NoT  -0.1828  0.006 -0.3368 -0.0288   True
#      OLD_7_T    YOUNG_5_T  -0.2247 0.0001 -0.3787 -0.0707   True
#      OLD_7_T  YOUNG_7_NoT  -0.1597 0.0343 -0.3137 -0.0056   True
#      OLD_7_T    YOUNG_7_T  -0.2525    0.0 -0.4065 -0.0984   True
# YOUNG_10_NoT   YOUNG_10_T  -0.1202  0.306 -0.2743  0.0338  False
# YOUNG_10_NoT  YOUNG_5_NoT  -0.1107 0.4386 -0.2647  0.0433  False
# YOUNG_10_NoT    YOUNG_5_T  -0.1526 0.0548 -0.3066  0.0014  False
# YOUNG_10_NoT  YOUNG_7_NoT  -0.0876 0.7824 -0.2416  0.0665  False
# YOUNG_10_NoT    YOUNG_7_T  -0.1804 0.0073 -0.3344 -0.0264   True
#   YOUNG_10_T  YOUNG_5_NoT   0.0095    1.0 -0.1445  0.1635  False
#   YOUNG_10_T    YOUNG_5_T  -0.0324 0.9999 -0.1864  0.1217  False
#   YOUNG_10_T  YOUNG_7_NoT   0.0327 0.9999 -0.1214  0.1867  False
#   YOUNG_10_T    YOUNG_7_T  -0.0601 0.9816 -0.2142  0.0939  False
#  YOUNG_5_NoT    YOUNG_5_T  -0.0419 0.9992 -0.1959  0.1121  False
#  YOUNG_5_NoT  YOUNG_7_NoT   0.0231    1.0 -0.1309  0.1772  False
#  YOUNG_5_NoT    YOUNG_7_T  -0.0697 0.9455 -0.2237  0.0844  False
#    YOUNG_5_T  YOUNG_7_NoT    0.065 0.9667  -0.089  0.2191  False
#    YOUNG_5_T    YOUNG_7_T  -0.0278    1.0 -0.1818  0.1263  False
#  YOUNG_7_NoT    YOUNG_7_T  -0.0928 0.7115 -0.2468  0.0612  False
# ----------------------------------------------------------------
#             Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================================
#       group1             group2       meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------------------
#   OLD_Baseline_NoT     OLD_Baseline_T   0.0281    1.0 -0.1243  0.1805  False
#   OLD_Baseline_NoT       OLD_Hcol_NoT   0.1633 0.0235  0.0109  0.3157   True
#   OLD_Baseline_NoT         OLD_Hcol_T   0.0442 0.9986 -0.1082  0.1966  False
#   OLD_Baseline_NoT      OLD_Hconc_NoT   0.2244 0.0001   0.072  0.3767   True
#   OLD_Baseline_NoT        OLD_Hconc_T   0.0588 0.9832 -0.0936  0.2112  False
#   OLD_Baseline_NoT YOUNG_Baseline_NoT  -0.1762 0.0088 -0.3285 -0.0238   True
#   OLD_Baseline_NoT   YOUNG_Baseline_T  -0.1859 0.0039 -0.3383 -0.0336   True
#   OLD_Baseline_NoT     YOUNG_Hcol_NoT  -0.0033    1.0 -0.1557  0.1491  False
#   OLD_Baseline_NoT       YOUNG_Hcol_T  -0.1448 0.0805 -0.2972  0.0075  False
#   OLD_Baseline_NoT    YOUNG_Hconc_NoT   0.0038    1.0 -0.1486  0.1562  False
#   OLD_Baseline_NoT      YOUNG_Hconc_T  -0.0998 0.5906 -0.2521  0.0526  False
#     OLD_Baseline_T       OLD_Hcol_NoT   0.1352 0.1401 -0.0172  0.2876  False
#     OLD_Baseline_T         OLD_Hcol_T   0.0161    1.0 -0.1363  0.1685  False
#     OLD_Baseline_T      OLD_Hconc_NoT   0.1963 0.0016  0.0439  0.3487   True
#     OLD_Baseline_T        OLD_Hconc_T   0.0307    1.0 -0.1217  0.1831  False
#     OLD_Baseline_T YOUNG_Baseline_NoT  -0.2042 0.0008 -0.3566 -0.0519   True
#     OLD_Baseline_T   YOUNG_Baseline_T   -0.214 0.0003 -0.3664 -0.0617   True
#     OLD_Baseline_T     YOUNG_Hcol_NoT  -0.0314 0.9999 -0.1838   0.121  False
#     OLD_Baseline_T       YOUNG_Hcol_T  -0.1729 0.0114 -0.3253 -0.0206   True
#     OLD_Baseline_T    YOUNG_Hconc_NoT  -0.0243    1.0 -0.1767  0.1281  False
#     OLD_Baseline_T      YOUNG_Hconc_T  -0.1279 0.2043 -0.2802  0.0245  False
#       OLD_Hcol_NoT         OLD_Hcol_T  -0.1191  0.304 -0.2715  0.0333  False
#       OLD_Hcol_NoT      OLD_Hconc_NoT   0.0611 0.9775 -0.0913  0.2135  False
#       OLD_Hcol_NoT        OLD_Hconc_T  -0.1045 0.5166 -0.2569  0.0479  False
#       OLD_Hcol_NoT YOUNG_Baseline_NoT  -0.3394    0.0 -0.4918 -0.1871   True
#       OLD_Hcol_NoT   YOUNG_Baseline_T  -0.3492    0.0 -0.5016 -0.1969   True
#       OLD_Hcol_NoT     YOUNG_Hcol_NoT  -0.1666 0.0185  -0.319 -0.0142   True
#       OLD_Hcol_NoT       YOUNG_Hcol_T  -0.3081    0.0 -0.4605 -0.1558   True
#       OLD_Hcol_NoT    YOUNG_Hconc_NoT  -0.1595 0.0309 -0.3119 -0.0071   True
#       OLD_Hcol_NoT      YOUNG_Hconc_T  -0.2631    0.0 -0.4154 -0.1107   True
#         OLD_Hcol_T      OLD_Hconc_NoT   0.1802 0.0064  0.0278  0.3326   True
#         OLD_Hcol_T        OLD_Hconc_T   0.0146    1.0 -0.1377   0.167  False
#         OLD_Hcol_T YOUNG_Baseline_NoT  -0.2203 0.0002 -0.3727  -0.068   True
#         OLD_Hcol_T   YOUNG_Baseline_T  -0.2301 0.0001 -0.3825 -0.0777   True
#         OLD_Hcol_T     YOUNG_Hcol_NoT  -0.0475 0.9972 -0.1998  0.1049  False
#         OLD_Hcol_T       YOUNG_Hcol_T   -0.189  0.003 -0.3414 -0.0366   True
#         OLD_Hcol_T    YOUNG_Hconc_NoT  -0.0404 0.9994 -0.1927   0.112  False
#         OLD_Hcol_T      YOUNG_Hconc_T   -0.144  0.085 -0.2963  0.0084  False
#      OLD_Hconc_NoT        OLD_Hconc_T  -0.1655   0.02 -0.3179 -0.0132   True
#      OLD_Hconc_NoT YOUNG_Baseline_NoT  -0.4005    0.0 -0.5529 -0.2481   True
#      OLD_Hconc_NoT   YOUNG_Baseline_T  -0.4103    0.0 -0.5627 -0.2579   True
#      OLD_Hconc_NoT     YOUNG_Hcol_NoT  -0.2276 0.0001   -0.38 -0.0753   True
#      OLD_Hconc_NoT       YOUNG_Hcol_T  -0.3692    0.0 -0.5216 -0.2168   True
#      OLD_Hconc_NoT    YOUNG_Hconc_NoT  -0.2205 0.0002 -0.3729 -0.0682   True
#      OLD_Hconc_NoT      YOUNG_Hconc_T  -0.3241    0.0 -0.4765 -0.1718   True
#        OLD_Hconc_T YOUNG_Baseline_NoT   -0.235    0.0 -0.3873 -0.0826   True
#        OLD_Hconc_T   YOUNG_Baseline_T  -0.2448    0.0 -0.3971 -0.0924   True
#        OLD_Hconc_T     YOUNG_Hcol_NoT  -0.0621 0.9745 -0.2145  0.0903  False
#        OLD_Hconc_T       YOUNG_Hcol_T  -0.2037 0.0008  -0.356 -0.0513   True
#        OLD_Hconc_T    YOUNG_Hconc_NoT   -0.055 0.9902 -0.2074  0.0974  False
#        OLD_Hconc_T      YOUNG_Hconc_T  -0.1586 0.0329  -0.311 -0.0062   True
# YOUNG_Baseline_NoT   YOUNG_Baseline_T  -0.0098    1.0 -0.1622  0.1426  False
# YOUNG_Baseline_NoT     YOUNG_Hcol_NoT   0.1729 0.0114  0.0205  0.3252   True
# YOUNG_Baseline_NoT       YOUNG_Hcol_T   0.0313 0.9999 -0.1211  0.1837  False
# YOUNG_Baseline_NoT    YOUNG_Hconc_NoT     0.18 0.0065  0.0276  0.3323   True
# YOUNG_Baseline_NoT      YOUNG_Hconc_T   0.0764 0.8932  -0.076  0.2288  False
#   YOUNG_Baseline_T     YOUNG_Hcol_NoT   0.1827 0.0052  0.0303   0.335   True
#   YOUNG_Baseline_T       YOUNG_Hcol_T   0.0411 0.9993 -0.1113  0.1935  False
#   YOUNG_Baseline_T    YOUNG_Hconc_NoT   0.1898 0.0028  0.0374  0.3421   True
#   YOUNG_Baseline_T      YOUNG_Hconc_T   0.0862 0.7883 -0.0662  0.2386  False
#     YOUNG_Hcol_NoT       YOUNG_Hcol_T  -0.1416 0.0979 -0.2939  0.0108  False
#     YOUNG_Hcol_NoT    YOUNG_Hconc_NoT   0.0071    1.0 -0.1453  0.1595  False
#     YOUNG_Hcol_NoT      YOUNG_Hconc_T  -0.0965 0.6417 -0.2489  0.0559  False
#       YOUNG_Hcol_T    YOUNG_Hconc_NoT   0.1487 0.0636 -0.0037   0.301  False
#       YOUNG_Hcol_T      YOUNG_Hconc_T   0.0451 0.9983 -0.1073  0.1975  False
#    YOUNG_Hconc_NoT      YOUNG_Hconc_T  -0.1036 0.5306  -0.256  0.0488  False
# ----------------------------------------------------------------------------

# %%
# STEP 7. visualization of mean RT OLD vs YOUNG considering predictors interactions

# calculate the mean RT for each possible interaction of all levels of the conditions
for Nfig in Nfig_levels:
    for Tipo in Tipo_levels:
        for TargetPresence in TargetPresence_levels:
            for Group in Group_levels:
                # filter the dataframe based on the current levels
                df_filtered = df_ideal[(df_ideal['Nfig'] == Nfig) &
                                                      (df_ideal['Tipo'] == Tipo) &
                                                      (df_ideal['TargetPresence'] == TargetPresence) &
                                                      (df_ideal['Group'] == Group)]
                
                # calculate the mean RT and standard error
                mean_rt = df_filtered['RT'].mean()
                std_err = df_filtered['RT'].sem()
                
                # Print the results
                print(f"Mean RT for Nfig={Nfig}, Tipo={Tipo}, TargetPresence={TargetPresence}, Group={Group}: {mean_rt}, SE: {std_err}")

# initialize a dictionary to store the jitter for each participant
jitter_dict = {}

# calculate the jitter for each possible interaction of all levels of the conditions
for Nfig in Nfig_levels:
    for Tipo in Tipo_levels:
        for TargetPresence in TargetPresence_levels:
            for Group in Group_levels:
                # filter the dataframe based on the current levels
                df_filtered = df_ideal[(df_ideal['Nfig'] == Nfig) &
                                                      (df_ideal['Tipo'] == Tipo) &
                                                      (df_ideal['TargetPresence'] == TargetPresence) &
                                                      (df_ideal['Group'] == Group)]
                
                # get the unique participant IDs
                IDs = df_filtered['ID'].unique()
                
                # calculate the jitter for each participant
                for ID in IDs:
                    jitter = np.random.normal(loc=0, scale=0.05)
                    
                    # store the jitter in the dictionary
                    jitter_dict[(Nfig, Tipo, TargetPresence, Group, ID)] = jitter
                    
# create a new column that combines the Tipo and Nfig levels
df_ideal['Tipo_Nfig'] = df_ideal['Tipo'] + '_' + df_ideal['Nfig'].astype(str)

# create a dictionary to map Group to color
color_dict = {'YOUNG': 'blue', 'OLD': 'violet'}
color_dict2 = {'YOUNG': 'pink', 'OLD': 'lightblue'}

# create two separate plots according to TargetPresence
for TargetPresence in TargetPresence_levels:
    # filter the DataFrame based on the current TargetPresence
    df_filtered = df_ideal[df_ideal['TargetPresence'] == TargetPresence]
    
    # create a bar plot with error bars
    plt.figure(figsize=(15, 8))
    sns.barplot(data=df_filtered, x='Tipo_Nfig', y='RT', hue='Group', palette=color_dict, capsize=.1)
    
    # get the unique 'Tipo_Nfig' values
    unique_Tipo_Nfig = df_filtered['Tipo_Nfig'].unique()
    
    # add individual participant mean RT as jittered data points
    for Group in Group_levels:
        for i, Tipo_Nfig in enumerate(unique_Tipo_Nfig):
            # filter the dataframe based on the current 'Tipo_Nfig' and 'Group'
            df_filtered_Tipo_Nfig_Group = df_filtered[(df_filtered['Tipo_Nfig'] == Tipo_Nfig) & (df_filtered['Group'] == Group)]
            
            # get the unique participant IDs
            IDs = df_filtered_Tipo_Nfig_Group['ID'].unique()
            
            # plot the mean RT for each participant
            for ID in IDs:
                # introduce a horizontal offset for both 'Young' and 'Old' groups
                offset = -0.2 if Group == 'OLD' else 0.2
                # marker = 'x' if Group == 'YOUNG' else 'o'
                plt.scatter(i + offset + jitter_dict[(Nfig, Tipo, TargetPresence, Group, ID)], df_filtered_Tipo_Nfig_Group[df_filtered_Tipo_Nfig_Group['ID'] == ID]['RT'].mean(), color=color_dict2[Group], alpha=0.5) #, marker=marker)
    
    plt.title(f'Mean Reaction Time (RT) for each condition (TargetPresence = {TargetPresence})')
    plt.xlabel('Condition (Tipo_Nfig)')
    plt.ylabel('Mean Reaction Time (RT)')
    
    # show the plot
    plt.show()
    
# create two separate BOXPLOTS according to TargetPresence
for TargetPresence in TargetPresence_levels:
    # filter the dataframe based on the current TargetPresence
    df_filtered = df_ideal[df_ideal['TargetPresence'] == TargetPresence]
    
    # set size of the plot
    plt.figure(figsize=(15, 8)) 
    # create a box plot with jittered data points
    sns.boxplot(data=df_filtered, x='Tipo_Nfig', y='RT', hue='Group', palette=color_dict)
    
    
    # get the unique 'Tipo_Nfig' values
    unique_Tipo_Nfig = df_filtered['Tipo_Nfig'].unique()
    
    # add individual participant mean RT as jittered data points
    for Group in Group_levels:
        for i, Tipo_Nfig in enumerate(unique_Tipo_Nfig):
            # filter the dataframe based on the current 'Tipo_Nfig' and 'Group'
            df_filtered_Tipo_Nfig_Group = df_filtered[(df_filtered['Tipo_Nfig'] == Tipo_Nfig) & (df_filtered['Group'] == Group)]
            
            # get the unique participant IDs
            IDs = df_filtered_Tipo_Nfig_Group['ID'].unique()
            
            # plot the mean RT for each participant
            for ID in IDs:
                # introduce a horizontal offset for both 'Young' and 'Old' groups
                offset = -0.2 if Group == 'OLD' else 0.2
                # marker = 'x' if Group == 'YOUNG' else 'o'
                plt.scatter(i + offset + jitter_dict[(Nfig, Tipo, TargetPresence, Group, ID)], df_filtered_Tipo_Nfig_Group[df_filtered_Tipo_Nfig_Group['ID'] == ID]['RT'].mean(), color=color_dict2[Group], alpha=0.5) #, marker=marker) 
    
    plt.ylim(0, 2)  # Set y-axis range
    plt.title(f'Mean Reaction Time (RT) for each condition (TargetPresence = {TargetPresence})')
    plt.xlabel('Condition (Tipo_Nfig)')
    plt.ylabel('Mean Reaction Time (RT)')
    
    # show the plot
    plt.show()
# Out:
# Mean RT for Nfig=5, Tipo=Baseline, TargetPresence=T, Group=OLD: 0.8494117543515987, SE: 0.06211141220879308
# Mean RT for Nfig=5, Tipo=Baseline, TargetPresence=T, Group=YOUNG: 0.6871641151263409, SE: 0.05758809076191021
# Mean RT for Nfig=5, Tipo=Baseline, TargetPresence=NoT, Group=OLD: 0.9308799860182543, SE: 0.06442029597702441
# Mean RT for Nfig=5, Tipo=Baseline, TargetPresence=NoT, Group=YOUNG: 0.677102771732249, SE: 0.06234096991173158
# Mean RT for Nfig=5, Tipo=Hconc, TargetPresence=T, Group=OLD: 0.835150131961023, SE: 0.047819005636368886
# Mean RT for Nfig=5, Tipo=Hconc, TargetPresence=T, Group=YOUNG: 0.8074843195939487, SE: 0.059148195705897966
# Mean RT for Nfig=5, Tipo=Hconc, TargetPresence=NoT, Group=OLD: 1.0223393995645083, SE: 0.0546931088670084
# Mean RT for Nfig=5, Tipo=Hconc, TargetPresence=NoT, Group=YOUNG: 0.8597696107287229, SE: 0.040444802645743655
# Mean RT for Nfig=5, Tipo=Hcol, TargetPresence=T, Group=OLD: 0.8701623469115117, SE: 0.057004636390958825
# Mean RT for Nfig=5, Tipo=Hcol, TargetPresence=T, Group=YOUNG: 0.7611613962435666, SE: 0.053640519844600644
# Mean RT for Nfig=5, Tipo=Hcol, TargetPresence=NoT, Group=OLD: 1.005766592049651, SE: 0.06400797784851453
# Mean RT for Nfig=5, Tipo=Hcol, TargetPresence=NoT, Group=YOUNG: 0.8446195234270231, SE: 0.07585858043149064
# Mean RT for Nfig=7, Tipo=Baseline, TargetPresence=T, Group=OLD: 1.0057049733412005, SE: 0.04528221916425517
# Mean RT for Nfig=7, Tipo=Baseline, TargetPresence=T, Group=YOUNG: 0.7290930707744586, SE: 0.05596832754065185
# Mean RT for Nfig=7, Tipo=Baseline, TargetPresence=NoT, Group=OLD: 0.8949569289535455, SE: 0.06099999336120812
# Mean RT for Nfig=7, Tipo=Baseline, TargetPresence=NoT, Group=YOUNG: 0.6868136472909995, SE: 0.05220518744352367
# Mean RT for Nfig=7, Tipo=Hconc, TargetPresence=T, Group=OLD: 0.9832461489330258, SE: 0.05727288179641276
# Mean RT for Nfig=7, Tipo=Hconc, TargetPresence=T, Group=YOUNG: 0.7527930990441996, SE: 0.05050904529627484
# Mean RT for Nfig=7, Tipo=Hconc, TargetPresence=NoT, Group=OLD: 1.1122652489701539, SE: 0.04981662567933669
# Mean RT for Nfig=7, Tipo=Hconc, TargetPresence=NoT, Group=YOUNG: 0.8365001449878527, SE: 0.06058589968320923
# Mean RT for Nfig=7, Tipo=Hcol, TargetPresence=T, Group=OLD: 0.9409567976839305, SE: 0.052505998101399345
# Mean RT for Nfig=7, Tipo=Hcol, TargetPresence=T, Group=YOUNG: 0.690617156588784, SE: 0.04115053538181486
# Mean RT for Nfig=7, Tipo=Hcol, TargetPresence=NoT, Group=OLD: 1.0013667925899277, SE: 0.05196775055241428
# Mean RT for Nfig=7, Tipo=Hcol, TargetPresence=NoT, Group=YOUNG: 0.9276040278175688, SE: 0.06405551385829694
# Mean RT for Nfig=10, Tipo=Baseline, TargetPresence=T, Group=OLD: 0.9201215996694662, SE: 0.05191326074611792
# Mean RT for Nfig=10, Tipo=Baseline, TargetPresence=T, Group=YOUNG: 0.7168812370396601, SE: 0.0567413948400605
# Mean RT for Nfig=10, Tipo=Baseline, TargetPresence=NoT, Group=OLD: 0.865129632990741, SE: 0.06827371089737237
# Mean RT for Nfig=10, Tipo=Baseline, TargetPresence=NoT, Group=YOUNG: 0.798590570198954, SE: 0.061830553395152504
# Mean RT for Nfig=10, Tipo=Hconc, TargetPresence=T, Group=OLD: 1.0490218371900955, SE: 0.06806955232550058
# Mean RT for Nfig=10, Tipo=Hconc, TargetPresence=T, Group=YOUNG: 0.8313849832275967, SE: 0.04875169095289497
# Mean RT for Nfig=10, Tipo=Hconc, TargetPresence=NoT, Group=OLD: 1.2294487098644775, SE: 0.04816508472142152
# Mean RT for Nfig=10, Tipo=Hconc, TargetPresence=NoT, Group=YOUNG: 1.0061351924684734, SE: 0.0561111400158912
# Mean RT for Nfig=10, Tipo=Hcol, TargetPresence=T, Group=OLD: 1.0123950549519702, SE: 0.05908109255641783
# Mean RT for Nfig=10, Tipo=Hcol, TargetPresence=T, Group=YOUNG: 0.8046474898382671, SE: 0.04877384425150092
# Mean RT for Nfig=10, Tipo=Hcol, TargetPresence=NoT, Group=OLD: 1.173699144664553, SE: 0.06255189398466739
# Mean RT for Nfig=10, Tipo=Hcol, TargetPresence=NoT, Group=YOUNG: 0.9088939683542455, SE: 0.04421115186406999

# %%
# STEP 8. T-test Accuracy    
    
# t-test mean accuracy OLD vs YOUNG without considering predictors
accuracy_old = df_ideal[df_ideal['Group'] == 'OLD']['Accuracy']
accuracy_young = df_ideal[df_ideal['Group'] == 'YOUNG']['Accuracy']

t_stat, p_value = ttest_ind(accuracy_old, accuracy_young)
print(f"t-statistic: {t_stat}, p-value: {p_value}")
# Out:
# t-statistic: 28.950473039883715, p-value: 8.299226659540848e-137

# %%
# STEP 9. visualization of mean Accuracy OLD vs YOUNG without considering predictors

# calculate mean accuracy + standard error for YOUNG & OLD
mean_acc_young = df_ideal[df_ideal['Group'] == 'YOUNG']['Accuracy'].mean()
std_err_acc_young = df_ideal[df_ideal['Group'] == 'YOUNG']['Accuracy'].sem()
mean_acc_old = df_ideal[df_ideal['Group'] == 'OLD']['Accuracy'].mean()
std_err_acc_old = df_ideal[df_ideal['Group'] == 'OLD']['Accuracy'].sem() 
print(f"YOUNG mean Accuracy: {mean_acc_young}, YOUNG SE: {std_err_acc_young}")
print(f"OLD mean Accuracy: {mean_acc_old}, OLD SE: {std_err_acc_old} ")

# mean accuracy of each participant
mean_acc_young_ID = df_ideal[df_ideal['Group'] == 'YOUNG'].groupby('ID')['Accuracy'].mean()
mean_acc_old_ID = df_ideal[df_ideal['Group'] == 'OLD'].groupby('ID')['Accuracy'].mean()

# create a BAR plot
plt.figure(figsize=(10, 6))
plt.bar(['YOUNG', 'OLD'], [mean_acc_young, mean_acc_old], yerr=[std_err_acc_young, std_err_acc_old], capsize=5, color=['blue', 'violet'], label='Mean Accuracy with SE')

# create jitter for each participant data point
jitter_y = np.random.normal(loc=0, scale=0.05, size=len(mean_acc_young_ID))
jitter_o = np.random.normal(loc=0, scale=0.05, size=len(mean_acc_old_ID))

# add individual participant accuracy as jittered data points
plt.scatter(np.zeros(len(mean_acc_young_ID)) + jitter_y, mean_acc_young_ID, color='pink', alpha=0.5, label='Individual Accuracy (YOUNG)')
plt.scatter(np.ones(len(mean_acc_old_ID)) + jitter_o, mean_acc_old_ID, color='lightblue', alpha=0.5, label='Individual Accuracy (OLD)')

# add significance star
if p_value < 0.001:
    sig = '***'  # Highly significant
elif p_value < 0.01:
    sig = '**'  # Very significant
elif p_value < 0.05:
    sig = '*'  # Significant
else:
    sig = 'n.s.'  # Not significant
    
# position of the star or "n.s." is midway of the bars, slightly above the highest error bar
plt.text(0.5, max(mean_acc_young + std_err_acc_young, mean_acc_old + std_err_acc_old) + 0.1, sig, ha='center', va='bottom', color='black', fontsize=20)

# add line connecting the bars
y_max = max(mean_acc_young + std_err_acc_young, mean_acc_old + std_err_acc_old) + 0.1
plt.plot([0, 1], [y_max, y_max], color='black')

plt.xlabel('Group')
plt.ylabel('Mean Accuracy')
plt.title('Mean Accuracy Comparison between YOUNG and OLD')
plt.ylim(0.6, 1)  # Set y-axis range
plt.xticks([0, 1], ['YOUNG', 'OLD'])
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()


# create a BOXPLOT
plt.figure(figsize=(10, 6))
data_acc = [mean_acc_young_ID, mean_acc_old_ID]
plt.boxplot(data_acc, labels=['YOUNG', 'OLD'], patch_artist=True, boxprops=dict(facecolor='lightgrey', color='black', alpha=0.5), medianprops=dict(color='red'))

# In order to visualize also single data points, create a jitter for each participant's data point
jitter_y = np.random.normal(loc=1, scale=0.05, size=len(mean_acc_young_ID))
jitter_o = np.random.normal(loc=2, scale=0.05, size=len(mean_acc_old_ID))

# Add individual participant RTs as jittered data points
plt.scatter(jitter_y, mean_acc_young_ID, color='pink', alpha=0.5, label='Individual RT (YOUNG)')
plt.scatter(jitter_o, mean_acc_old_ID, color='lightblue', alpha=0.5, label='Individual RT (OLD)')

# Following the t-test results, add significance star if any
if p_value < 0.001:
    sig = '***'  # Highly significant
elif p_value < 0.01:
    sig = '**'  # Very significant
elif p_value < 0.05:
    sig = '*'  # Significant
else:
    sig = 'n.s.'  # Not significant

# position of the star or "n.s." is midway of the bars, slightly above the highest error bar
plt.text(1.5, max(mean_acc_young + std_err_acc_young, mean_acc_old + std_err_acc_old) + 0.1, sig, ha='center', va='bottom', color='black', fontsize=20)

# add line connecting the bars
y_max = max(mean_acc_young + std_err_acc_young, mean_acc_old + std_err_acc_old) + 0.1
plt.plot([1, 2], [y_max, y_max], color='black')

plt.xlabel('Group')
plt.ylabel('Mean Accuracy')
plt.title('Mean Accuracy Comparison between YOUNG and OLD')
plt.ylim(0.6, 1)  # Set y-axis range
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()
# Out:
# YOUNG mean Accuracy: 0.7294060228298321, YOUNG SE: 0.0029271733455900856
# OLD mean Accuracy: 0.8622628077754401, OLD SE: 0.003534338499727044

# %%
# STEP 10. checking assumptions for parametric methods

# Assumption 1: Normality
shapiro_test_accuracy = stats.shapiro(df_ideal['Accuracy'])
print(f"Shapiro-Wilk test for Accuracy: statistic = {shapiro_test_accuracy.statistic}, p-value = {shapiro_test_accuracy.pvalue}")

# Assumption 2: Homogeneity of variance
levene_test_acc = stats.levene(df_ideal['Accuracy'][df_ideal['Group'] == 'YOUNG'],
                            df_ideal['Accuracy'][df_ideal['Group'] == 'OLD'])
print(f"Levene's test statistic: {levene_test_acc.statistic}, p-value: {levene_test_acc.pvalue}")
# Out:
# Shapiro-Wilk test for Accuracy: statistic = 0.9462456107139587, p-value = 2.1868517651006485e-19
# Levene's test statistic: 19.30772497194996, p-value: 1.2223874848351802e-05

# %%
# STEP 11. ANOVA (or non-parametric test)

# create a formula for the ANOVA
formula2 = 'Accuracy ~ C(Group) + C(Nfig) + C(Tipo) + C(TargetPresence) + C(Group):C(Nfig) + C(Group):C(Tipo) + C(Group):C(TargetPresence) + C(Group):C(Nfig):C(Tipo) + C(Group):C(Nfig):C(TargetPresence) + C(Group):C(Tipo):C(TargetPresence)'

model2 = ols(formula2, df_ideal).fit()
anova_table2 = sm.stats.anova_lm(model2, typ=2)

print(anova_table2)
# Out:
#                                       sum_sq      df            F  \
# C(Group)                            4.765750     1.0  2090.288315
# C(Nfig)                             1.868734     2.0   409.819388
# C(Tipo)                             0.978952     2.0   214.687246
# C(TargetPresence)                   0.705330     1.0   309.362409
# C(Group):C(Nfig)                    0.011927     2.0     2.615648
# C(Group):C(Tipo)                    0.011938     2.0     2.618037
# C(Group):C(TargetPresence)          0.038748     1.0    16.995321
# C(Group):C(Nfig):C(Tipo)            0.078099     8.0     4.281839
# C(Group):C(Nfig):C(TargetPresence)  0.032125     4.0     3.522548
# C(Group):C(Tipo):C(TargetPresence)  0.005333     4.0     0.584728
# Residual                            2.398506  1052.0          NaN
#
#                                            PR(>F)
# C(Group)                            3.221135e-252
# C(Nfig)                             2.463140e-132
# C(Tipo)                              6.464899e-79
# C(TargetPresence)                    6.626381e-61
# C(Group):C(Nfig)                     7.359586e-02
# C(Group):C(Tipo)                     7.342114e-02
# C(Group):C(TargetPresence)           4.042137e-05
# C(Group):C(Nfig):C(Tipo)             4.407472e-05
# C(Group):C(Nfig):C(TargetPresence)   7.263369e-03
# C(Group):C(Tipo):C(TargetPresence)   6.737619e-01
# Residual                                      NaN

# %%
# STEP 12. POST-HOC tests

# perform post-hoc test for 'Group'
posthoc_group = pairwise_tukeyhsd(df_ideal['Accuracy'], df_ideal['Group'], alpha=0.05)
print(posthoc_group)

# perform post-hoc test for 'Nfig'
posthoc_nfig = pairwise_tukeyhsd(df_ideal['Accuracy'], df_ideal['Nfig'], alpha=0.05)
print(posthoc_nfig)

# perform post-hoc test for 'Tipo'
posthoc_tipo = pairwise_tukeyhsd(df_ideal['Accuracy'], df_ideal['Tipo'], alpha=0.05)
print(posthoc_tipo)

# perform post-hoc test for 'TargetPresence'
posthoc_target_presence = pairwise_tukeyhsd(df_ideal['Accuracy'], df_ideal['TargetPresence'], alpha=0.05)
print(posthoc_target_presence)

# post-hoc test for 'Group:Nfig' interaction
posthoc_group_nfig = pairwise_tukeyhsd(df_ideal['Accuracy'], df_ideal['Group_Nfig'], alpha=0.05)
print(posthoc_group_nfig)

# post-hoc test for 'Group:Tipo' interaction
posthoc_group_tipo = pairwise_tukeyhsd(df_ideal['Accuracy'], df_ideal['Group_Tipo'], alpha=0.05)
print(posthoc_group_tipo)

# post-hoc test for 'Group:TargetPresence' interaction
posthoc_group_target_presence = pairwise_tukeyhsd(df_ideal['Accuracy'], df_ideal['Group_TargetPresence'], alpha=0.05)
print(posthoc_group_target_presence)

# post-hoc test for 'Group:Nfig:Tipo' interaction
posthoc_group_nfig_tipo = pairwise_tukeyhsd(df_ideal['Accuracy'], df_ideal['Group_Nfig_Tipo'], alpha=0.05)
print(posthoc_group_nfig_tipo)

# post-hoc test for 'Group:Nfig:TargetPresence' interaction
posthoc_group_nfig_target_presence = pairwise_tukeyhsd(df_ideal['Accuracy'], df_ideal['Group_Nfig_TargetPresence'], alpha=0.05)
print(posthoc_group_nfig_target_presence)

# post-hoc test for 'Group:Tipo:TargetPresence' interaction
posthoc_group_tipo_target_presence = pairwise_tukeyhsd(df_ideal['Accuracy'], df_ideal['Group_Tipo_TargetPresence'], alpha=0.05)
print(posthoc_group_tipo_target_presence)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#    OLD  YOUNG  -0.1329   0.0 -0.1419 -0.1239   True
# ---------------------------------------------------
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      5      7  -0.0714    0.0 -0.0874 -0.0554   True
#      5     10  -0.0987    0.0 -0.1147 -0.0826   True
#      7     10  -0.0273 0.0002 -0.0433 -0.0113   True
# ----------------------------------------------------
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ======================================================
#  group1  group2 meandiff p-adj   lower   upper  reject
# ------------------------------------------------------
# Baseline   Hcol  -0.0724    0.0 -0.0892 -0.0556   True
# Baseline  Hconc  -0.0485    0.0 -0.0653 -0.0317   True
#     Hcol  Hconc   0.0239 0.0025  0.0071  0.0407   True
# ------------------------------------------------------
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#    NoT      T  -0.0511   0.0 -0.0627 -0.0395   True
# ---------------------------------------------------
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
#  group1   group2  meandiff p-adj   lower   upper  reject
# --------------------------------------------------------
#   OLD_10    OLD_5   0.1062    0.0  0.0873  0.1251   True
#   OLD_10    OLD_7   0.0337    0.0  0.0147  0.0526   True
#   OLD_10 YOUNG_10  -0.1235    0.0 -0.1425 -0.1046   True
#   OLD_10  YOUNG_5  -0.0324    0.0 -0.0514 -0.0135   True
#   OLD_10  YOUNG_7  -0.1027    0.0 -0.1216 -0.0838   True
#    OLD_5    OLD_7  -0.0725    0.0 -0.0915 -0.0536   True
#    OLD_5 YOUNG_10  -0.2298    0.0 -0.2487 -0.2108   True
#    OLD_5  YOUNG_5  -0.1386    0.0 -0.1576 -0.1197   True
#    OLD_5  YOUNG_7  -0.2089    0.0 -0.2278   -0.19   True
#    OLD_7 YOUNG_10  -0.1572    0.0 -0.1762 -0.1383   True
#    OLD_7  YOUNG_5  -0.0661    0.0  -0.085 -0.0472   True
#    OLD_7  YOUNG_7  -0.1364    0.0 -0.1553 -0.1174   True
# YOUNG_10  YOUNG_5   0.0911    0.0  0.0722    0.11   True
# YOUNG_10  YOUNG_7   0.0209 0.0211  0.0019  0.0398   True
#  YOUNG_5  YOUNG_7  -0.0703    0.0 -0.0892 -0.0513   True
# --------------------------------------------------------
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================================
#     group1         group2     meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------------
#   OLD_Baseline       OLD_Hcol  -0.0805    0.0 -0.1013 -0.0596   True
#   OLD_Baseline      OLD_Hconc  -0.0518    0.0 -0.0726  -0.031   True
#   OLD_Baseline YOUNG_Baseline  -0.1404    0.0 -0.1613 -0.1196   True
#   OLD_Baseline     YOUNG_Hcol  -0.2047    0.0 -0.2255 -0.1839   True
#   OLD_Baseline    YOUNG_Hconc  -0.1856    0.0 -0.2065 -0.1648   True
#       OLD_Hcol      OLD_Hconc   0.0287 0.0012  0.0079  0.0495   True
#       OLD_Hcol YOUNG_Baseline    -0.06    0.0 -0.0808 -0.0392   True
#       OLD_Hcol     YOUNG_Hcol  -0.1243    0.0 -0.1451 -0.1034   True
#       OLD_Hcol    YOUNG_Hconc  -0.1052    0.0  -0.126 -0.0844   True
#      OLD_Hconc YOUNG_Baseline  -0.0887    0.0 -0.1095 -0.0679   True
#      OLD_Hconc     YOUNG_Hcol  -0.1529    0.0 -0.1738 -0.1321   True
#      OLD_Hconc    YOUNG_Hconc  -0.1339    0.0 -0.1547 -0.1131   True
# YOUNG_Baseline     YOUNG_Hcol  -0.0643    0.0 -0.0851 -0.0435   True
# YOUNG_Baseline    YOUNG_Hconc  -0.0452    0.0  -0.066 -0.0244   True
#     YOUNG_Hcol    YOUNG_Hconc   0.0191 0.0944 -0.0017  0.0399  False
# --------------------------------------------------------------------
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================
#   group1    group2  meandiff p-adj  lower   upper  reject
# ---------------------------------------------------------
#   OLD_NoT     OLD_T  -0.0631   0.0 -0.0788 -0.0474   True
#   OLD_NoT YOUNG_NoT  -0.1448   0.0 -0.1605 -0.1292   True
#   OLD_NoT   YOUNG_T   -0.184   0.0 -0.1996 -0.1683   True
#     OLD_T YOUNG_NoT  -0.0817   0.0 -0.0974 -0.0661   True
#     OLD_T   YOUNG_T  -0.1209   0.0 -0.1365 -0.1052   True
# YOUNG_NoT   YOUNG_T  -0.0391   0.0 -0.0548 -0.0235   True
# ---------------------------------------------------------
#            Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================================
#       group1            group2      meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------------------
#   OLD_10_Baseline       OLD_10_Hcol  -0.0847    0.0 -0.1196 -0.0497   True
#   OLD_10_Baseline      OLD_10_Hconc  -0.0604    0.0 -0.0953 -0.0255   True
#   OLD_10_Baseline    OLD_5_Baseline   0.0995    0.0  0.0646  0.1344   True
#   OLD_10_Baseline        OLD_5_Hcol   0.0195  0.891 -0.0154  0.0544  False
#   OLD_10_Baseline       OLD_5_Hconc   0.0545    0.0  0.0196  0.0895   True
#   OLD_10_Baseline    OLD_7_Baseline   0.0275 0.3429 -0.0074  0.0625  False
#   OLD_10_Baseline        OLD_7_Hcol  -0.0492 0.0001 -0.0841 -0.0142   True
#   OLD_10_Baseline       OLD_7_Hconc  -0.0224 0.7246 -0.0573  0.0125  False
#   OLD_10_Baseline YOUNG_10_Baseline   -0.155    0.0 -0.1899 -0.1201   True
#   OLD_10_Baseline     YOUNG_10_Hcol  -0.1879    0.0 -0.2229  -0.153   True
#   OLD_10_Baseline    YOUNG_10_Hconc  -0.1728    0.0 -0.2077 -0.1379   True
#   OLD_10_Baseline  YOUNG_5_Baseline  -0.0244 0.5751 -0.0593  0.0105  False
#   OLD_10_Baseline      YOUNG_5_Hcol   -0.123    0.0 -0.1579  -0.088   True
#   OLD_10_Baseline     YOUNG_5_Hconc   -0.095    0.0   -0.13 -0.0601   True
#   OLD_10_Baseline  YOUNG_7_Baseline  -0.1149    0.0 -0.1498   -0.08   True
#   OLD_10_Baseline      YOUNG_7_Hcol  -0.1762    0.0 -0.2112 -0.1413   True
#   OLD_10_Baseline     YOUNG_7_Hconc  -0.1621    0.0  -0.197 -0.1271   True
#       OLD_10_Hcol      OLD_10_Hconc   0.0243 0.5864 -0.0107  0.0592  False
#       OLD_10_Hcol    OLD_5_Baseline   0.1842    0.0  0.1492  0.2191   True
#       OLD_10_Hcol        OLD_5_Hcol   0.1042    0.0  0.0692  0.1391   True
#       OLD_10_Hcol       OLD_5_Hconc   0.1392    0.0  0.1043  0.1742   True
#       OLD_10_Hcol    OLD_7_Baseline   0.1122    0.0  0.0773  0.1471   True
#       OLD_10_Hcol        OLD_7_Hcol   0.0355 0.0419  0.0005  0.0704   True
#       OLD_10_Hcol       OLD_7_Hconc   0.0623    0.0  0.0273  0.0972   True
#       OLD_10_Hcol YOUNG_10_Baseline  -0.0703    0.0 -0.1053 -0.0354   True
#       OLD_10_Hcol     YOUNG_10_Hcol  -0.1033    0.0 -0.1382 -0.0683   True
#       OLD_10_Hcol    YOUNG_10_Hconc  -0.0881    0.0 -0.1231 -0.0532   True
#       OLD_10_Hcol  YOUNG_5_Baseline   0.0603    0.0  0.0253  0.0952   True
#       OLD_10_Hcol      YOUNG_5_Hcol  -0.0383 0.0158 -0.0732 -0.0034   True
#       OLD_10_Hcol     YOUNG_5_Hconc  -0.0104 0.9999 -0.0453  0.0246  False
#       OLD_10_Hcol  YOUNG_7_Baseline  -0.0302 0.1897 -0.0652  0.0047  False
#       OLD_10_Hcol      YOUNG_7_Hcol  -0.0915    0.0 -0.1265 -0.0566   True
#       OLD_10_Hcol     YOUNG_7_Hconc  -0.0774    0.0 -0.1123 -0.0424   True
#      OLD_10_Hconc    OLD_5_Baseline   0.1599    0.0   0.125  0.1948   True
#      OLD_10_Hconc        OLD_5_Hcol   0.0799    0.0   0.045  0.1148   True
#      OLD_10_Hconc       OLD_5_Hconc    0.115    0.0    0.08  0.1499   True
#      OLD_10_Hconc    OLD_7_Baseline   0.0879    0.0   0.053  0.1229   True
#      OLD_10_Hconc        OLD_7_Hcol   0.0112 0.9997 -0.0237  0.0462  False
#      OLD_10_Hconc       OLD_7_Hconc    0.038 0.0176  0.0031  0.0729   True
#      OLD_10_Hconc YOUNG_10_Baseline  -0.0946    0.0 -0.1295 -0.0596   True
#      OLD_10_Hconc     YOUNG_10_Hcol  -0.1275    0.0 -0.1625 -0.0926   True
#      OLD_10_Hconc    YOUNG_10_Hconc  -0.1124    0.0 -0.1473 -0.0775   True
#      OLD_10_Hconc  YOUNG_5_Baseline    0.036 0.0353  0.0011  0.0709   True
#      OLD_10_Hconc      YOUNG_5_Hcol  -0.0626    0.0 -0.0975 -0.0276   True
#      OLD_10_Hconc     YOUNG_5_Hconc  -0.0346 0.0552 -0.0696  0.0003  False
#      OLD_10_Hconc  YOUNG_7_Baseline  -0.0545    0.0 -0.0894 -0.0195   True
#      OLD_10_Hconc      YOUNG_7_Hcol  -0.1158    0.0 -0.1507 -0.0809   True
#      OLD_10_Hconc     YOUNG_7_Hconc  -0.1016    0.0 -0.1366 -0.0667   True
#    OLD_5_Baseline        OLD_5_Hcol    -0.08    0.0 -0.1149 -0.0451   True
#    OLD_5_Baseline       OLD_5_Hconc   -0.045  0.001 -0.0799   -0.01   True
#    OLD_5_Baseline    OLD_7_Baseline   -0.072    0.0 -0.1069  -0.037   True
#    OLD_5_Baseline        OLD_7_Hcol  -0.1487    0.0 -0.1836 -0.1137   True
#    OLD_5_Baseline       OLD_7_Hconc  -0.1219    0.0 -0.1568  -0.087   True
#    OLD_5_Baseline YOUNG_10_Baseline  -0.2545    0.0 -0.2894 -0.2195   True
#    OLD_5_Baseline     YOUNG_10_Hcol  -0.2874    0.0 -0.3224 -0.2525   True
#    OLD_5_Baseline    YOUNG_10_Hconc  -0.2723    0.0 -0.3072 -0.2374   True
#    OLD_5_Baseline  YOUNG_5_Baseline  -0.1239    0.0 -0.1588  -0.089   True
#    OLD_5_Baseline      YOUNG_5_Hcol  -0.2225    0.0 -0.2574 -0.1875   True
#    OLD_5_Baseline     YOUNG_5_Hconc  -0.1945    0.0 -0.2295 -0.1596   True
#    OLD_5_Baseline  YOUNG_7_Baseline  -0.2144    0.0 -0.2493 -0.1795   True
#    OLD_5_Baseline      YOUNG_7_Hcol  -0.2757    0.0 -0.3107 -0.2408   True
#    OLD_5_Baseline     YOUNG_7_Hconc  -0.2615    0.0 -0.2965 -0.2266   True
#        OLD_5_Hcol       OLD_5_Hconc    0.035 0.0484  0.0001    0.07   True
#        OLD_5_Hcol    OLD_7_Baseline    0.008    1.0 -0.0269   0.043  False
#        OLD_5_Hcol        OLD_7_Hcol  -0.0687    0.0 -0.1036 -0.0337   True
#        OLD_5_Hcol       OLD_7_Hconc  -0.0419 0.0039 -0.0768  -0.007   True
#        OLD_5_Hcol YOUNG_10_Baseline  -0.1745    0.0 -0.2094 -0.1395   True
#        OLD_5_Hcol     YOUNG_10_Hcol  -0.2074    0.0 -0.2424 -0.1725   True
#        OLD_5_Hcol    YOUNG_10_Hconc  -0.1923    0.0 -0.2272 -0.1574   True
#        OLD_5_Hcol  YOUNG_5_Baseline  -0.0439 0.0017 -0.0788  -0.009   True
#        OLD_5_Hcol      YOUNG_5_Hcol  -0.1425    0.0 -0.1774 -0.1075   True
#        OLD_5_Hcol     YOUNG_5_Hconc  -0.1145    0.0 -0.1495 -0.0796   True
#        OLD_5_Hcol  YOUNG_7_Baseline  -0.1344    0.0 -0.1693 -0.0995   True
#        OLD_5_Hcol      YOUNG_7_Hcol  -0.1957    0.0 -0.2307 -0.1608   True
#        OLD_5_Hcol     YOUNG_7_Hconc  -0.1815    0.0 -0.2165 -0.1466   True
#       OLD_5_Hconc    OLD_7_Baseline   -0.027 0.3794 -0.0619  0.0079  False
#       OLD_5_Hconc        OLD_7_Hcol  -0.1037    0.0 -0.1387 -0.0688   True
#       OLD_5_Hconc       OLD_7_Hconc  -0.0769    0.0 -0.1119  -0.042   True
#       OLD_5_Hconc YOUNG_10_Baseline  -0.2095    0.0 -0.2445 -0.1746   True
#       OLD_5_Hconc     YOUNG_10_Hcol  -0.2425    0.0 -0.2774 -0.2075   True
#       OLD_5_Hconc    YOUNG_10_Hconc  -0.2274    0.0 -0.2623 -0.1924   True
#       OLD_5_Hconc  YOUNG_5_Baseline  -0.0789    0.0 -0.1139  -0.044   True
#       OLD_5_Hconc      YOUNG_5_Hcol  -0.1775    0.0 -0.2124 -0.1426   True
#       OLD_5_Hconc     YOUNG_5_Hconc  -0.1496    0.0 -0.1845 -0.1146   True
#       OLD_5_Hconc  YOUNG_7_Baseline  -0.1694    0.0 -0.2044 -0.1345   True
#       OLD_5_Hconc      YOUNG_7_Hcol  -0.2308    0.0 -0.2657 -0.1958   True
#       OLD_5_Hconc     YOUNG_7_Hconc  -0.2166    0.0 -0.2515 -0.1817   True
#    OLD_7_Baseline        OLD_7_Hcol  -0.0767    0.0 -0.1117 -0.0418   True
#    OLD_7_Baseline       OLD_7_Hconc  -0.0499 0.0001 -0.0849  -0.015   True
#    OLD_7_Baseline YOUNG_10_Baseline  -0.1825    0.0 -0.2175 -0.1476   True
#    OLD_7_Baseline     YOUNG_10_Hcol  -0.2155    0.0 -0.2504 -0.1805   True
#    OLD_7_Baseline    YOUNG_10_Hconc  -0.2003    0.0 -0.2353 -0.1654   True
#    OLD_7_Baseline  YOUNG_5_Baseline  -0.0519    0.0 -0.0869  -0.017   True
#    OLD_7_Baseline      YOUNG_5_Hcol  -0.1505    0.0 -0.1854 -0.1156   True
#    OLD_7_Baseline     YOUNG_5_Hconc  -0.1226    0.0 -0.1575 -0.0876   True
#    OLD_7_Baseline  YOUNG_7_Baseline  -0.1424    0.0 -0.1774 -0.1075   True
#    OLD_7_Baseline      YOUNG_7_Hcol  -0.2038    0.0 -0.2387 -0.1688   True
#    OLD_7_Baseline     YOUNG_7_Hconc  -0.1896    0.0 -0.2245 -0.1546   True
#        OLD_7_Hcol       OLD_7_Hconc   0.0268 0.3955 -0.0082  0.0617  False
#        OLD_7_Hcol YOUNG_10_Baseline  -0.1058    0.0 -0.1408 -0.0709   True
#        OLD_7_Hcol     YOUNG_10_Hcol  -0.1387    0.0 -0.1737 -0.1038   True
#        OLD_7_Hcol    YOUNG_10_Hconc  -0.1236    0.0 -0.1586 -0.0887   True
#        OLD_7_Hcol  YOUNG_5_Baseline   0.0248 0.5463 -0.0102  0.0597  False
#        OLD_7_Hcol      YOUNG_5_Hcol  -0.0738    0.0 -0.1087 -0.0388   True
#        OLD_7_Hcol     YOUNG_5_Hconc  -0.0459 0.0007 -0.0808 -0.0109   True
#        OLD_7_Hcol  YOUNG_7_Baseline  -0.0657    0.0 -0.1007 -0.0308   True
#        OLD_7_Hcol      YOUNG_7_Hcol   -0.127    0.0  -0.162 -0.0921   True
#        OLD_7_Hcol     YOUNG_7_Hconc  -0.1129    0.0 -0.1478 -0.0779   True
#       OLD_7_Hconc YOUNG_10_Baseline  -0.1326    0.0 -0.1675 -0.0976   True
#       OLD_7_Hconc     YOUNG_10_Hcol  -0.1655    0.0 -0.2005 -0.1306   True
#       OLD_7_Hconc    YOUNG_10_Hconc  -0.1504    0.0 -0.1853 -0.1155   True
#       OLD_7_Hconc  YOUNG_5_Baseline   -0.002    1.0 -0.0369  0.0329  False
#       OLD_7_Hconc      YOUNG_5_Hcol  -0.1006    0.0 -0.1355 -0.0656   True
#       OLD_7_Hconc     YOUNG_5_Hconc  -0.0726    0.0 -0.1076 -0.0377   True
#       OLD_7_Hconc  YOUNG_7_Baseline  -0.0925    0.0 -0.1274 -0.0576   True
#       OLD_7_Hconc      YOUNG_7_Hcol  -0.1538    0.0 -0.1888 -0.1189   True
#       OLD_7_Hconc     YOUNG_7_Hconc  -0.1396    0.0 -0.1746 -0.1047   True
# YOUNG_10_Baseline     YOUNG_10_Hcol  -0.0329 0.0921 -0.0679   0.002  False
# YOUNG_10_Baseline    YOUNG_10_Hconc  -0.0178 0.9482 -0.0528  0.0171  False
# YOUNG_10_Baseline  YOUNG_5_Baseline   0.1306    0.0  0.0956  0.1655   True
# YOUNG_10_Baseline      YOUNG_5_Hcol    0.032  0.119 -0.0029   0.067  False
# YOUNG_10_Baseline     YOUNG_5_Hconc     0.06    0.0   0.025  0.0949   True
# YOUNG_10_Baseline  YOUNG_7_Baseline   0.0401  0.008  0.0052   0.075   True
# YOUNG_10_Baseline      YOUNG_7_Hcol  -0.0212 0.8017 -0.0562  0.0137  False
# YOUNG_10_Baseline     YOUNG_7_Hconc  -0.0071    1.0  -0.042  0.0279  False
#     YOUNG_10_Hcol    YOUNG_10_Hconc   0.0151 0.9897 -0.0198  0.0501  False
#     YOUNG_10_Hcol  YOUNG_5_Baseline   0.1635    0.0  0.1286  0.1985   True
#     YOUNG_10_Hcol      YOUNG_5_Hcol    0.065    0.0    0.03  0.0999   True
#     YOUNG_10_Hcol     YOUNG_5_Hconc   0.0929    0.0  0.0579  0.1278   True
#     YOUNG_10_Hcol  YOUNG_7_Baseline    0.073    0.0  0.0381   0.108   True
#     YOUNG_10_Hcol      YOUNG_7_Hcol   0.0117 0.9995 -0.0232  0.0467  False
#     YOUNG_10_Hcol     YOUNG_7_Hconc   0.0259  0.462 -0.0091  0.0608  False
#    YOUNG_10_Hconc  YOUNG_5_Baseline   0.1484    0.0  0.1135  0.1833   True
#    YOUNG_10_Hconc      YOUNG_5_Hcol   0.0498 0.0001  0.0149  0.0848   True
#    YOUNG_10_Hconc     YOUNG_5_Hconc   0.0778    0.0  0.0428  0.1127   True
#    YOUNG_10_Hconc  YOUNG_7_Baseline   0.0579    0.0   0.023  0.0929   True
#    YOUNG_10_Hconc      YOUNG_7_Hcol  -0.0034    1.0 -0.0383  0.0315  False
#    YOUNG_10_Hconc     YOUNG_7_Hconc   0.0108 0.9998 -0.0242  0.0457  False
#  YOUNG_5_Baseline      YOUNG_5_Hcol  -0.0986    0.0 -0.1335 -0.0636   True
#  YOUNG_5_Baseline     YOUNG_5_Hconc  -0.0706    0.0 -0.1056 -0.0357   True
#  YOUNG_5_Baseline  YOUNG_7_Baseline  -0.0905    0.0 -0.1254 -0.0555   True
#  YOUNG_5_Baseline      YOUNG_7_Hcol  -0.1518    0.0 -0.1868 -0.1169   True
#  YOUNG_5_Baseline     YOUNG_7_Hconc  -0.1376    0.0 -0.1726 -0.1027   True
#      YOUNG_5_Hcol     YOUNG_5_Hconc   0.0279 0.3176  -0.007  0.0629  False
#      YOUNG_5_Hcol  YOUNG_7_Baseline   0.0081    1.0 -0.0269   0.043  False
#      YOUNG_5_Hcol      YOUNG_7_Hcol  -0.0533    0.0 -0.0882 -0.0183   True
#      YOUNG_5_Hcol     YOUNG_7_Hconc  -0.0391 0.0118  -0.074 -0.0041   True
#     YOUNG_5_Hconc  YOUNG_7_Baseline  -0.0199 0.8749 -0.0548  0.0151  False
#     YOUNG_5_Hconc      YOUNG_7_Hcol  -0.0812    0.0 -0.1161 -0.0462   True
#     YOUNG_5_Hconc     YOUNG_7_Hconc   -0.067    0.0  -0.102 -0.0321   True
#  YOUNG_7_Baseline      YOUNG_7_Hcol  -0.0613    0.0 -0.0963 -0.0264   True
#  YOUNG_7_Baseline     YOUNG_7_Hconc  -0.0472 0.0004 -0.0821 -0.0122   True
#      YOUNG_7_Hcol     YOUNG_7_Hconc   0.0142  0.995 -0.0208  0.0491  False
# --------------------------------------------------------------------------
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#   OLD_10_NoT     OLD_10_T  -0.0749    0.0 -0.1027  -0.047   True
#   OLD_10_NoT    OLD_5_NoT   0.0975    0.0  0.0697  0.1254   True
#   OLD_10_NoT      OLD_5_T     0.04 0.0002  0.0121  0.0678   True
#   OLD_10_NoT    OLD_7_NoT   0.0246 0.1424 -0.0032  0.0525  False
#   OLD_10_NoT      OLD_7_T  -0.0322 0.0089   -0.06 -0.0043   True
#   OLD_10_NoT YOUNG_10_NoT  -0.1501    0.0 -0.1779 -0.1222   True
#   OLD_10_NoT   YOUNG_10_T  -0.1719    0.0 -0.1998 -0.1441   True
#   OLD_10_NoT  YOUNG_5_NoT  -0.0433    0.0 -0.0712 -0.0155   True
#   OLD_10_NoT    YOUNG_5_T  -0.0965    0.0 -0.1243 -0.0686   True
#   OLD_10_NoT  YOUNG_7_NoT  -0.1189    0.0 -0.1468 -0.0911   True
#   OLD_10_NoT    YOUNG_7_T  -0.1613    0.0 -0.1892 -0.1335   True
#     OLD_10_T    OLD_5_NoT   0.1724    0.0  0.1446  0.2003   True
#     OLD_10_T      OLD_5_T   0.1149    0.0   0.087  0.1427   True
#     OLD_10_T    OLD_7_NoT   0.0995    0.0  0.0717  0.1274   True
#     OLD_10_T      OLD_7_T   0.0427    0.0  0.0149  0.0705   True
#     OLD_10_T YOUNG_10_NoT  -0.0752    0.0  -0.103 -0.0473   True
#     OLD_10_T   YOUNG_10_T   -0.097    0.0 -0.1249 -0.0692   True
#     OLD_10_T  YOUNG_5_NoT   0.0316 0.0115  0.0037  0.0594   True
#     OLD_10_T    YOUNG_5_T  -0.0216 0.3177 -0.0494  0.0063  False
#     OLD_10_T  YOUNG_7_NoT  -0.0441    0.0 -0.0719 -0.0162   True
#     OLD_10_T    YOUNG_7_T  -0.0865    0.0 -0.1143 -0.0586   True
#    OLD_5_NoT      OLD_5_T  -0.0576    0.0 -0.0854 -0.0297   True
#    OLD_5_NoT    OLD_7_NoT  -0.0729    0.0 -0.1007 -0.0451   True
#    OLD_5_NoT      OLD_7_T  -0.1297    0.0 -0.1576 -0.1019   True
#    OLD_5_NoT YOUNG_10_NoT  -0.2476    0.0 -0.2754 -0.2198   True
#    OLD_5_NoT   YOUNG_10_T  -0.2695    0.0 -0.2973 -0.2416   True
#    OLD_5_NoT  YOUNG_5_NoT  -0.1409    0.0 -0.1687  -0.113   True
#    OLD_5_NoT    YOUNG_5_T   -0.194    0.0 -0.2218 -0.1662   True
#    OLD_5_NoT  YOUNG_7_NoT  -0.2165    0.0 -0.2443 -0.1886   True
#    OLD_5_NoT    YOUNG_7_T  -0.2589    0.0 -0.2867  -0.231   True
#      OLD_5_T    OLD_7_NoT  -0.0153 0.8159 -0.0432  0.0125  False
#      OLD_5_T      OLD_7_T  -0.0722    0.0    -0.1 -0.0443   True
#      OLD_5_T YOUNG_10_NoT    -0.19    0.0 -0.2179 -0.1622   True
#      OLD_5_T   YOUNG_10_T  -0.2119    0.0 -0.2397 -0.1841   True
#      OLD_5_T  YOUNG_5_NoT  -0.0833    0.0 -0.1111 -0.0555   True
#      OLD_5_T    YOUNG_5_T  -0.1364    0.0 -0.1643 -0.1086   True
#      OLD_5_T  YOUNG_7_NoT  -0.1589    0.0 -0.1868 -0.1311   True
#      OLD_5_T    YOUNG_7_T  -0.2013    0.0 -0.2292 -0.1735   True
#    OLD_7_NoT      OLD_7_T  -0.0568    0.0 -0.0847  -0.029   True
#    OLD_7_NoT YOUNG_10_NoT  -0.1747    0.0 -0.2026 -0.1469   True
#    OLD_7_NoT   YOUNG_10_T  -0.1966    0.0 -0.2244 -0.1687   True
#    OLD_7_NoT  YOUNG_5_NoT   -0.068    0.0 -0.0958 -0.0401   True
#    OLD_7_NoT    YOUNG_5_T  -0.1211    0.0 -0.1489 -0.0933   True
#    OLD_7_NoT  YOUNG_7_NoT  -0.1436    0.0 -0.1714 -0.1157   True
#    OLD_7_NoT    YOUNG_7_T   -0.186    0.0 -0.2138 -0.1581   True
#      OLD_7_T YOUNG_10_NoT  -0.1179    0.0 -0.1457   -0.09   True
#      OLD_7_T   YOUNG_10_T  -0.1397    0.0 -0.1676 -0.1119   True
#      OLD_7_T  YOUNG_5_NoT  -0.0111 0.9778  -0.039  0.0167  False
#      OLD_7_T    YOUNG_5_T  -0.0643    0.0 -0.0921 -0.0364   True
#      OLD_7_T  YOUNG_7_NoT  -0.0868    0.0 -0.1146 -0.0589   True
#      OLD_7_T    YOUNG_7_T  -0.1292    0.0  -0.157 -0.1013   True
# YOUNG_10_NoT   YOUNG_10_T  -0.0219 0.2971 -0.0497   0.006  False
# YOUNG_10_NoT  YOUNG_5_NoT   0.1067    0.0  0.0789  0.1346   True
# YOUNG_10_NoT    YOUNG_5_T   0.0536    0.0  0.0258  0.0814   True
# YOUNG_10_NoT  YOUNG_7_NoT   0.0311 0.0139  0.0033   0.059   True
# YOUNG_10_NoT    YOUNG_7_T  -0.0113 0.9757 -0.0391  0.0166  False
#   YOUNG_10_T  YOUNG_5_NoT   0.1286    0.0  0.1008  0.1564   True
#   YOUNG_10_T    YOUNG_5_T   0.0755    0.0  0.0476  0.1033   True
#   YOUNG_10_T  YOUNG_7_NoT    0.053    0.0  0.0251  0.0808   True
#   YOUNG_10_T    YOUNG_7_T   0.0106 0.9851 -0.0173  0.0384  False
#  YOUNG_5_NoT    YOUNG_5_T  -0.0531    0.0  -0.081 -0.0253   True
#  YOUNG_5_NoT  YOUNG_7_NoT  -0.0756    0.0 -0.1035 -0.0478   True
#  YOUNG_5_NoT    YOUNG_7_T   -0.118    0.0 -0.1459 -0.0902   True
#    YOUNG_5_T  YOUNG_7_NoT  -0.0225 0.2559 -0.0503  0.0054  False
#    YOUNG_5_T    YOUNG_7_T  -0.0649    0.0 -0.0927  -0.037   True
#  YOUNG_7_NoT    YOUNG_7_T  -0.0424    0.0 -0.0702 -0.0146   True
# ----------------------------------------------------------------
#             Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================================
#       group1             group2       meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------------------
#   OLD_Baseline_NoT     OLD_Baseline_T  -0.0582    0.0 -0.0895 -0.0269   True
#   OLD_Baseline_NoT       OLD_Hcol_NoT  -0.0791    0.0 -0.1104 -0.0478   True
#   OLD_Baseline_NoT         OLD_Hcol_T    -0.14    0.0 -0.1713 -0.1087   True
#   OLD_Baseline_NoT      OLD_Hconc_NoT  -0.0458 0.0001 -0.0771 -0.0145   True
#   OLD_Baseline_NoT        OLD_Hconc_T   -0.116    0.0 -0.1473 -0.0846   True
#   OLD_Baseline_NoT YOUNG_Baseline_NoT  -0.1511    0.0 -0.1824 -0.1198   True
#   OLD_Baseline_NoT   YOUNG_Baseline_T  -0.1881    0.0 -0.2194 -0.1568   True
#   OLD_Baseline_NoT     YOUNG_Hcol_NoT  -0.2158    0.0 -0.2471 -0.1845   True
#   OLD_Baseline_NoT       YOUNG_Hcol_T  -0.2519    0.0 -0.2832 -0.2206   True
#   OLD_Baseline_NoT    YOUNG_Hconc_NoT  -0.1926    0.0 -0.2239 -0.1613   True
#   OLD_Baseline_NoT      YOUNG_Hconc_T  -0.2369    0.0 -0.2682 -0.2056   True
#     OLD_Baseline_T       OLD_Hcol_NoT  -0.0209 0.5607 -0.0522  0.0104  False
#     OLD_Baseline_T         OLD_Hcol_T  -0.0818    0.0 -0.1131 -0.0505   True
#     OLD_Baseline_T      OLD_Hconc_NoT   0.0124 0.9793 -0.0189  0.0437  False
#     OLD_Baseline_T        OLD_Hconc_T  -0.0577    0.0  -0.089 -0.0264   True
#     OLD_Baseline_T YOUNG_Baseline_NoT  -0.0928    0.0 -0.1241 -0.0615   True
#     OLD_Baseline_T   YOUNG_Baseline_T  -0.1298    0.0 -0.1611 -0.0985   True
#     OLD_Baseline_T     YOUNG_Hcol_NoT  -0.1575    0.0 -0.1888 -0.1262   True
#     OLD_Baseline_T       YOUNG_Hcol_T  -0.1936    0.0 -0.2249 -0.1623   True
#     OLD_Baseline_T    YOUNG_Hconc_NoT  -0.1344    0.0 -0.1657 -0.1031   True
#     OLD_Baseline_T      YOUNG_Hconc_T  -0.1787    0.0   -0.21 -0.1474   True
#       OLD_Hcol_NoT         OLD_Hcol_T  -0.0609    0.0 -0.0922 -0.0296   True
#       OLD_Hcol_NoT      OLD_Hconc_NoT   0.0333 0.0256   0.002  0.0646   True
#       OLD_Hcol_NoT        OLD_Hconc_T  -0.0368 0.0069 -0.0681 -0.0055   True
#       OLD_Hcol_NoT YOUNG_Baseline_NoT  -0.0719    0.0 -0.1032 -0.0406   True
#       OLD_Hcol_NoT   YOUNG_Baseline_T  -0.1089    0.0 -0.1402 -0.0776   True
#       OLD_Hcol_NoT     YOUNG_Hcol_NoT  -0.1367    0.0  -0.168 -0.1054   True
#       OLD_Hcol_NoT       YOUNG_Hcol_T  -0.1727    0.0 -0.2041 -0.1414   True
#       OLD_Hcol_NoT    YOUNG_Hconc_NoT  -0.1135    0.0 -0.1448 -0.0822   True
#       OLD_Hcol_NoT      YOUNG_Hconc_T  -0.1578    0.0 -0.1891 -0.1265   True
#         OLD_Hcol_T      OLD_Hconc_NoT   0.0942    0.0  0.0629  0.1255   True
#         OLD_Hcol_T        OLD_Hconc_T   0.0241  0.328 -0.0072  0.0554  False
#         OLD_Hcol_T YOUNG_Baseline_NoT   -0.011  0.992 -0.0423  0.0203  False
#         OLD_Hcol_T   YOUNG_Baseline_T   -0.048    0.0 -0.0793 -0.0167   True
#         OLD_Hcol_T     YOUNG_Hcol_NoT  -0.0758    0.0 -0.1071 -0.0445   True
#         OLD_Hcol_T       YOUNG_Hcol_T  -0.1118    0.0 -0.1431 -0.0805   True
#         OLD_Hcol_T    YOUNG_Hconc_NoT  -0.0526    0.0 -0.0839 -0.0213   True
#         OLD_Hcol_T      YOUNG_Hconc_T  -0.0969    0.0 -0.1282 -0.0656   True
#      OLD_Hconc_NoT        OLD_Hconc_T  -0.0701    0.0 -0.1014 -0.0388   True
#      OLD_Hconc_NoT YOUNG_Baseline_NoT  -0.1052    0.0 -0.1365 -0.0739   True
#      OLD_Hconc_NoT   YOUNG_Baseline_T  -0.1422    0.0 -0.1735 -0.1109   True
#      OLD_Hconc_NoT     YOUNG_Hcol_NoT    -0.17    0.0 -0.2013 -0.1387   True
#      OLD_Hconc_NoT       YOUNG_Hcol_T   -0.206    0.0 -0.2374 -0.1747   True
#      OLD_Hconc_NoT    YOUNG_Hconc_NoT  -0.1468    0.0 -0.1781 -0.1155   True
#      OLD_Hconc_NoT      YOUNG_Hconc_T  -0.1911    0.0 -0.2224 -0.1598   True
#        OLD_Hconc_T YOUNG_Baseline_NoT  -0.0351 0.0132 -0.0664 -0.0038   True
#        OLD_Hconc_T   YOUNG_Baseline_T  -0.0721    0.0 -0.1034 -0.0408   True
#        OLD_Hconc_T     YOUNG_Hcol_NoT  -0.0998    0.0 -0.1311 -0.0685   True
#        OLD_Hconc_T       YOUNG_Hcol_T  -0.1359    0.0 -0.1672 -0.1046   True
#        OLD_Hconc_T    YOUNG_Hconc_NoT  -0.0767    0.0  -0.108 -0.0454   True
#        OLD_Hconc_T      YOUNG_Hconc_T   -0.121    0.0 -0.1523 -0.0897   True
# YOUNG_Baseline_NoT   YOUNG_Baseline_T   -0.037 0.0065 -0.0683 -0.0057   True
# YOUNG_Baseline_NoT     YOUNG_Hcol_NoT  -0.0647    0.0  -0.096 -0.0334   True
# YOUNG_Baseline_NoT       YOUNG_Hcol_T  -0.1008    0.0 -0.1321 -0.0695   True
# YOUNG_Baseline_NoT    YOUNG_Hconc_NoT  -0.0415 0.0009 -0.0728 -0.0102   True
# YOUNG_Baseline_NoT      YOUNG_Hconc_T  -0.0859    0.0 -0.1172 -0.0546   True
#   YOUNG_Baseline_T     YOUNG_Hcol_NoT  -0.0277 0.1414  -0.059  0.0036  False
#   YOUNG_Baseline_T       YOUNG_Hcol_T  -0.0638    0.0 -0.0951 -0.0325   True
#   YOUNG_Baseline_T    YOUNG_Hconc_NoT  -0.0045    1.0 -0.0359  0.0268  False
#   YOUNG_Baseline_T      YOUNG_Hconc_T  -0.0489    0.0 -0.0802 -0.0176   True
#     YOUNG_Hcol_NoT       YOUNG_Hcol_T  -0.0361 0.0092 -0.0674 -0.0048   True
#     YOUNG_Hcol_NoT    YOUNG_Hconc_NoT   0.0232  0.389 -0.0081  0.0545  False
#     YOUNG_Hcol_NoT      YOUNG_Hconc_T  -0.0211 0.5411 -0.0524  0.0102  False
#       YOUNG_Hcol_T    YOUNG_Hconc_NoT   0.0593    0.0   0.028  0.0906   True
#       YOUNG_Hcol_T      YOUNG_Hconc_T   0.0149 0.9215 -0.0164  0.0463  False
#    YOUNG_Hconc_NoT      YOUNG_Hconc_T  -0.0443 0.0002 -0.0756  -0.013   True
# ----------------------------------------------------------------------------

# %%
# STEP 13. visualization of mean Accuracy OLD vs YOUNG considering predictors interactions

# calculate the mean Accuracy for each possible interaction of all levels of the conditions
for Nfig in Nfig_levels:
    for Tipo in Tipo_levels:
        for TargetPresence in TargetPresence_levels:
            for Group in Group_levels:
                # filter the dataframe based on the current levels
                df_filtered = df_ideal[(df_ideal['Nfig'] == Nfig) &
                                                      (df_ideal['Tipo'] == Tipo) &
                                                      (df_ideal['TargetPresence'] == TargetPresence) &
                                                      (df_ideal['Group'] == Group)]
                
                # calculate the mean RT and standard error
                mean_acc = df_filtered['Accuracy'].mean()
                std_err_acc = df_filtered['Accuracy'].sem()
                
                # print the results
                print(f"Mean Accuracy for Nfig={Nfig}, Tipo={Tipo}, TargetPresence={TargetPresence}, Group={Group}: {mean_acc}, SE: {std_err_acc}")

# create two separate BAR plots according to TargetPresence
for TargetPresence in TargetPresence_levels:
    # filter the dataframe based on the current TargetPresence
    df_filtered = df_ideal[df_ideal['TargetPresence'] == TargetPresence]
    
    # create a bar plot with error bars
    plt.figure(figsize=(15, 8))
    sns.barplot(data=df_filtered, x='Tipo_Nfig', y='Accuracy', hue='Group', palette=color_dict, capsize=.1)
    
    # get the unique 'Tipo_Nfig' values
    unique_Tipo_Nfig = df_filtered['Tipo_Nfig'].unique()
    
    # add individual participant mean RT as jittered data points
    for Group in Group_levels:
        for i, Tipo_Nfig in enumerate(unique_Tipo_Nfig):
            # filter the dataframe based on the current 'Tipo_Nfig' and 'Group'
            df_filtered_Tipo_Nfig_Group = df_filtered[(df_filtered['Tipo_Nfig'] == Tipo_Nfig) & (df_filtered['Group'] == Group)]
            
            # get the unique participant IDs
            IDs = df_filtered_Tipo_Nfig_Group['ID'].unique()
            
            # plot the mean RT for each participant
            for ID in IDs:
                # introduce a horizontal offset for both 'Young' and 'Old' groups
                offset = -0.2 if Group == 'OLD' else 0.2
                # marker = 'x' if Group == 'YOUNG' else 'o'
                plt.scatter(i + offset + jitter_dict[(Nfig, Tipo, TargetPresence, Group, ID)], df_filtered_Tipo_Nfig_Group[df_filtered_Tipo_Nfig_Group['ID'] == ID]['Accuracy'].mean(), color=color_dict2[Group], alpha=0.5) #, marker=marker) 
    
    plt.ylim(0.6, 1.1)  # Set y-axis range
    plt.title(f'Mean Accuracy for each condition (TargetPresence = {TargetPresence})')
    plt.xlabel('Condition (Tipo_Nfig)')
    plt.ylabel('Mean Accuracy')
    
    # show the plot
    plt.show()
    
# create two separate BOXPLOTS according to TargetPresence
for TargetPresence in TargetPresence_levels:
    # filter the dataframe based on the current TargetPresence
    df_filtered = df_ideal[df_ideal['TargetPresence'] == TargetPresence]
    
    # set size of the plot
    plt.figure(figsize=(15, 8)) 
    # create a box plot with jittered data points
    sns.boxplot(data=df_filtered, x='Tipo_Nfig', y='Accuracy', hue='Group', palette=color_dict)
    
    
    # get the unique 'Tipo_Nfig' values
    unique_Tipo_Nfig = df_filtered['Tipo_Nfig'].unique()
    
    # add individual participant mean RT as jittered data points
    for Group in Group_levels:
        for i, Tipo_Nfig in enumerate(unique_Tipo_Nfig):
            # filter the dataframe based on the current 'Tipo_Nfig' and 'Group'
            df_filtered_Tipo_Nfig_Group = df_filtered[(df_filtered['Tipo_Nfig'] == Tipo_Nfig) & (df_filtered['Group'] == Group)]
            
            # get the unique participant IDs
            IDs = df_filtered_Tipo_Nfig_Group['ID'].unique()
            
            # plot the mean RT for each participant
            for ID in IDs:
                # introduce a horizontal offset for both 'Young' and 'Old' groups
                offset = -0.2 if Group == 'OLD' else 0.2
                # marker = 'x' if Group == 'YOUNG' else 'o'
                plt.scatter(i + offset + jitter_dict[(Nfig, Tipo, TargetPresence, Group, ID)], df_filtered_Tipo_Nfig_Group[df_filtered_Tipo_Nfig_Group['ID'] == ID]['Accuracy'].mean(), color=color_dict2[Group], alpha=0.5) #, marker=marker) 
    
    plt.ylim(0.6, 1.1)  # Set y-axis range
    plt.title(f'Mean Accuracy for each condition (TargetPresence = {TargetPresence})')
    plt.xlabel('Condition (Tipo_Nfig)')
    plt.ylabel('Mean Accuracy')
    
    # show the plot
    plt.show()
# Out:
# Mean Accuracy for Nfig=5, Tipo=Baseline, TargetPresence=T, Group=OLD: 0.9445941508039074, SE: 0.008617440187289644
# Mean Accuracy for Nfig=5, Tipo=Baseline, TargetPresence=T, Group=YOUNG: 0.8208751355651294, SE: 0.009872056295731523
# Mean Accuracy for Nfig=5, Tipo=Baseline, TargetPresence=NoT, Group=OLD: 0.9823898958319827, SE: 0.00561792454117837
# Mean Accuracy for Nfig=5, Tipo=Baseline, TargetPresence=NoT, Group=YOUNG: 0.8583029687090125, SE: 0.00731769167314425
# Mean Accuracy for Nfig=5, Tipo=Hconc, TargetPresence=T, Group=OLD: 0.8877788086489957, SE: 0.008887043556547148
# Mean Accuracy for Nfig=5, Tipo=Hconc, TargetPresence=T, Group=YOUNG: 0.7449494117732411, SE: 0.008281814199939595
# Mean Accuracy for Nfig=5, Tipo=Hconc, TargetPresence=NoT, Group=OLD: 0.9492953955163272, SE: 0.007974167712809902
# Mean Accuracy for Nfig=5, Tipo=Hconc, TargetPresence=NoT, Group=YOUNG: 0.792960518780854, SE: 0.008956542221880644
# Mean Accuracy for Nfig=5, Tipo=Hcol, TargetPresence=T, Group=OLD: 0.8468060010149915, SE: 0.011252227154402902
# Mean Accuracy for Nfig=5, Tipo=Hcol, TargetPresence=T, Group=YOUNG: 0.7040481227682899, SE: 0.007898762711121032
# Mean Accuracy for Nfig=5, Tipo=Hcol, TargetPresence=NoT, Group=OLD: 0.9201792130650882, SE: 0.009231787097654834
# Mean Accuracy for Nfig=5, Tipo=Hcol, TargetPresence=NoT, Group=YOUNG: 0.7780135765457831, SE: 0.008996088086314524
# Mean Accuracy for Nfig=7, Tipo=Baseline, TargetPresence=T, Group=OLD: 0.859152200658316, SE: 0.011277221596721709
# Mean Accuracy for Nfig=7, Tipo=Baseline, TargetPresence=T, Group=YOUNG: 0.721267838124249, SE: 0.007837858401390646
# Mean Accuracy for Nfig=7, Tipo=Baseline, TargetPresence=NoT, Group=OLD: 0.9239112877355412, SE: 0.009465927101974993
# Mean Accuracy for Nfig=7, Tipo=Baseline, TargetPresence=NoT, Group=YOUNG: 0.776928085764377, SE: 0.009042105752043051
# Mean Accuracy for Nfig=7, Tipo=Hconc, TargetPresence=T, Group=OLD: 0.812845653269464, SE: 0.010596077292431894
# Mean Accuracy for Nfig=7, Tipo=Hconc, TargetPresence=T, Group=YOUNG: 0.6791464995498724, SE: 0.0052055574986262995
# Mean Accuracy for Nfig=7, Tipo=Hconc, TargetPresence=NoT, Group=OLD: 0.870338060310878, SE: 0.009374446496638888
# Mean Accuracy for Nfig=7, Tipo=Hconc, TargetPresence=NoT, Group=YOUNG: 0.7247415087834493, SE: 0.01081137736127949
# Mean Accuracy for Nfig=7, Tipo=Hcol, TargetPresence=T, Group=OLD: 0.7906999874781039, SE: 0.01015327973966267
# Mean Accuracy for Nfig=7, Tipo=Hcol, TargetPresence=T, Group=YOUNG: 0.6748121885720274, SE: 0.00625929051414915
# Mean Accuracy for Nfig=7, Tipo=Hcol, TargetPresence=NoT, Group=OLD: 0.8389260688182586, SE: 0.007787158469642142
# Mean Accuracy for Nfig=7, Tipo=Hcol, TargetPresence=NoT, Group=YOUNG: 0.7007475223377583, SE: 0.006759661976916981
# Mean Accuracy for Nfig=10, Tipo=Baseline, TargetPresence=T, Group=OLD: 0.8278998381084719, SE: 0.009138267404684439
# Mean Accuracy for Nfig=10, Tipo=Baseline, TargetPresence=T, Group=YOUNG: 0.7000843916647325, SE: 0.0074760619876662856
# Mean Accuracy for Nfig=10, Tipo=Baseline, TargetPresence=NoT, Group=OLD: 0.9000887555731492, SE: 0.010489153989434844
# Mean Accuracy for Nfig=10, Tipo=Baseline, TargetPresence=NoT, Group=YOUNG: 0.7179213395625669, SE: 0.008197698602348077
# Mean Accuracy for Nfig=10, Tipo=Hconc, TargetPresence=T, Group=OLD: 0.7579145508206427, SE: 0.009472942558017578
# Mean Accuracy for Nfig=10, Tipo=Hconc, TargetPresence=T, Group=YOUNG: 0.671496317991144, SE: 0.003779087723697722
# Mean Accuracy for Nfig=10, Tipo=Hconc, TargetPresence=NoT, Group=OLD: 0.8492570922616884, SE: 0.009205493007576893
# Mean Accuracy for Nfig=10, Tipo=Hconc, TargetPresence=NoT, Group=YOUNG: 0.7108761447677256, SE: 0.009435042047349778
# Mean Accuracy for Nfig=10, Tipo=Hcol, TargetPresence=T, Group=OLD: 0.7487659868372922, SE: 0.01131070243950319
# Mean Accuracy for Nfig=10, Tipo=Hcol, TargetPresence=T, Group=YOUNG: 0.671883355367617, SE: 0.003862532177271592
# Mean Accuracy for Nfig=10, Tipo=Hcol, TargetPresence=NoT, Group=OLD: 0.8098875932048202, SE: 0.00894351817473806
# Mean Accuracy for Nfig=10, Tipo=Hcol, TargetPresence=NoT, Group=YOUNG: 0.6802534843091497, SE: 0.0062605945741829065
